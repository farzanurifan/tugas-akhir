# %%
import pandas as pd

def analize(label, tipe, positif):
    df = pd.read_csv('Results/Categorization/'+ tipe +'.csv')
    
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    kosong = 0
    
    for index in range(0, len(df)):
        labels = df['label'][index].split('|')
        
        if type(df['pred_multiple'][index]) != float:
            preds = df['pred_multiple'][index].split('|')

            if label in labels and label in preds:
                tp += 1
            elif label not in labels and label not in preds:
                tn += 1
            elif label not in labels and label in preds:
                if positif:
                    print(df['review'][index], '~')
                    print()
                    print('label\t:', df['label'][index])
                    print('term\t:', df['terms'][index])
#                     error = []
#                     for i, aspek in enumerate(df['pred_multiple'][index].split('|')):
#                         if aspek == label:
#                             error.append(df['terms'][index].split('|')[i])
#                     print(' | '.join(error))
                    print('pred\t:', df['pred_multiple'][index])
                    print('_____________________________________________________________________________________________________')
                    print()
                fp += 1
            elif label in labels and label not in preds:
                if not positif:
                    print(df['review'][index], '~')
                    print()
                    print('label\t:', df['label'][index])
                    print('term\t:', df['terms'][index])
#                     error = []
#                     for i, aspek in enumerate(df['pred_multiple'][index].split('|')):
#                         if aspek != label:
#                             error.append(df['terms'][index].split('|')[i])
#                     print(' | '.join(error))
                    print('pred\t:', df['pred_multiple'][index])
                    print()
                    print()
                fn += 1
        elif label in labels:
            fn += 1
            if not positif:
                print(df['review'][index], '~')
                print(df['label'][index])
                print('---')
                print('')
        else:
            tn += 1
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1 = 2 * ((precision * recall) / (precision + recall))
    print(tp, tn, fp, fn, precision, recall, f1)
    return tp, tn, fp, fn, precision, recall, f1

# %%
import pandas as pd

analize("VALUE", '20-ner', True)
# Out:
# we, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude. ~
#
# label	: SERVICE
# term	: place|place|staff
# pred	: VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# i have eaten at saul, many times, the food is always consistently, outrageously good. ~
#
# label	: FOOD
# term	: food|times|food
# pred	: FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# chow fun was dry; pork shu mai was more than usually greasy and had to share a table with loud and rude family. ~
#
# label	: FOOD|FOOD
# term	: chow|pork|table|family
# pred	: FOOD|FOOD|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# service was divine, oysters where a sensual as they come, and the price can't be beat!!! ~
#
# label	: SERVICE|FOOD
# term	: price|service|service|oysters|price
# pred	: VALUE|SERVICE|SERVICE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# everything is always cooked to perfection, the service is excellent, the decor cool and understated. ~
#
# label	: SERVICE|AMBIENCE
# term	: service|everything|service|decor
# pred	: VALUE|VALUE|VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# i had the duck breast special on my last visit and it was not incredible. ~
#
# label	: FOOD
# term	: duck|breast|visit
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the food is very average...the thai fusion stuff is a bit too sweet, every thing they serve is too sweet here. ~
#
# label	: FOOD|FOOD
# term	: food|food|fusion|stuff|thing
# pred	: FOOD|FOOD|FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the only thing i moderately enjoyed was their grilled chicken special with edamame puree. ~
#
# label	: FOOD
# term	: thing|chicken|edamame|puree
# pred	: VALUE|FOOD|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the decor is night tho...but they really need to clean that vent in the ceiling...its quite un-appetizing, and kills your effort to make this place look sleek and modern. ~
#
# label	: AMBIENCE|AMBIENCE|AMBIENCE
# term	: place|decor|ceiling|effort|place|look
# pred	: AMBIENCE|AMBIENCE|AMBIENCE|VALUE|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# however, it's the service that leaves a bad taste in my mouth. ~
#
# label	: SERVICE
# term	: service|service|taste|mouth
# pred	: VALUE|VALUE|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# i happen to have a policy that goes along with a little bit of self-respect, which includes not letting a waiter intimidate me, i.e. make me feel bad asking for trivialities like water, or the check. ~
#
# label	: SERVICE
# term	: policy|trivialities|water|check
# pred	: VALUE|VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the rice to fish ration was also good and they didn't try to overpack the rice. ~
#
# label	: FOOD
# term	: rice|fish|ration|rice
# pred	: FOOD|FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# we took advantage of the half price sushi deal on saturday so it was well worth it. ~
#
# label	: FOOD
# term	: price|half|price|sushi|deal
# pred	: VALUE|VALUE|VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the service varys from day to day- sometimes they're very nice, and sometimes not. ~
#
# label	: SERVICE
# term	: service|service|varys
# pred	: SERVICE|SERVICE|VALUE
# _____________________________________________________________________________________________________
#
# the ambience is pretty and nice for conversation, so a casual lunch here would probably be best. ~
#
# label	: AMBIENCE
# term	: ambience|conversation|lunch
# pred	: AMBIENCE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# if you've ever been along the river in weehawken you have an idea of the top of view the chart house has to offer. ~
#
# label	: AMBIENCE
# term	: idea|view|chart|house
# pred	: VALUE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# yes, they use fancy ingredients, but even fancy ingredients don't make for good pizza unless someone knows how to get the crust right. ~
#
# label	: FOOD|FOOD|FOOD
# term	: pizza|ingredients|ingredients|pizza|someone|crust
# pred	: FOOD|FOOD|FOOD|FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# i think i've had some the worst meals of my life at minnow. ~
#
# label	: FOOD
# term	: meals|life|minnow
# pred	: FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the seafood is amazing, there's a good wine list, and the ever-changing menu always offers some great surprises. ~
#
# label	: FOOD|FOOD|FOOD
# term	: seafood|wine|list|surprises
# pred	: FOOD|FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the combination of super-fresh ingredients in the dishes are unusual but really delicious. ~
#
# label	: FOOD
# term	: combination|ingredients|dishes
# pred	: VALUE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# best pastrami i ever had and great portion without being ridiculous. ~
#
# label	: FOOD|FOOD
# term	: pastrami|portion
# pred	: FOOD|VALUE
# _____________________________________________________________________________________________________
#
# my wife had the fried shrimp which are huge and loved it. ~
#
# label	: FOOD|FOOD
# term	: wife|shrimp
# pred	: VALUE|FOOD
# _____________________________________________________________________________________________________
#
# my wife and i always enjoy the young, not always well trained but nevertheless friendly, staff, all of whom have a story. ~
#
# label	: SERVICE
# term	: wife|staff|story
# pred	: VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the service is excellent, the decor is great, and the food is delicious and comes in large portions. ~
#
# label	: SERVICE|AMBIENCE|FOOD|FOOD
# term	: food|service|service|decor|food|portions
# pred	: FOOD|SERVICE|SERVICE|AMBIENCE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# this place is incredibly tiny. ~
#
# label	: AMBIENCE
# term	: place|place
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the hostess is rude to the point of being offensive. ~
#
# label	: SERVICE
# term	: point
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# we have been to this place many times, and always have great food, wine, and service. ~
#
# label	: FOOD|FOOD|SERVICE
# term	: place|food|service|place|times|food|wine|service
# pred	: VALUE|FOOD|SERVICE|VALUE|VALUE|FOOD|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# the people that work there are always so friendly you forget you are in new york sometimes. ~
#
# label	: SERVICE
# term	: people
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# i went there for lunch and the lunch was not as good as i expected from the reviews i read. ~
#
# label	: FOOD
# term	: lunch|lunch|reviews
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# there was a small wait, but shorter than i expected. ~
#
# label	: SERVICE
# term	: wait
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# this is the best sushi in new york city - hands down. ~
#
# label	: FOOD
# term	: sushi|hands
# pred	: FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the atmosphere isn't the greatest , but i suppose that's how they keep the prices down . ~
#
# label	: AMBIENCE
# term	: atmosphere|price|atmosphere|prices
# pred	: VALUE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the steak tartare is a great bet, they fix it for you at the table. ~
#
# label	: FOOD
# term	: steak|tartare|table
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# admittedly some nights inside the restaurant were rather warm, but the open kitchen is part of the charm. ~
#
# label	: AMBIENCE|AMBIENCE
# term	: restaurant|kitchen|part
# pred	: AMBIENCE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# it may be a bit packed on weekends, but the vibe is good and it is the best french food you will find in the area. ~
#
# label	: AMBIENCE|FOOD
# term	: food|vibe|food|area
# pred	: FOOD|AMBIENCE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# i'd highly recommend it for a special occasion and it provides and intimate setting and nice service. ~
#
# label	: AMBIENCE|SERVICE
# term	: high|service|occasion|setting|service
# pred	: VALUE|SERVICE|VALUE|AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# the exotic food is beautifully presented and is a delight in delicious combinations. ~
#
# label	: FOOD|FOOD
# term	: food|food|combinations
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the staff is incredibly helpful and attentive. ~
#
# label	: SERVICE
# term	: staff
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# i loved everythig about it-especially the shows and actors. ~
#
# label	: AMBIENCE|AMBIENCE
# term	: everythig|shows|actors
# pred	: VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# our server was very helpful and friendly. ~
#
# label	: SERVICE
# term	: server
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# bad service, bad food. ~
#
# label	: SERVICE|FOOD
# term	: food|service|service|food
# pred	: FOOD|VALUE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu. ~
#
# label	: FOOD
# term	: appetizer|selection|mozzarella
# pred	: FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# wait staff is blantently unappreciative of your business but its the best pie on the uws! ~
#
# label	: SERVICE|FOOD
# term	: staff|business
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the staff is no nonsense. ~
#
# label	: SERVICE
# term	: staff
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# when i lived upstate for a while i would buy freeze the bagels and they would still be better than any else. ~
#
# label	: FOOD
# term	: while|bagels
# pred	: VALUE|FOOD
# _____________________________________________________________________________________________________
#
# food was very good as well, considering that we tried the budget selection (though i wish the pork belly that i ordered was roasted a bit longer, so that fat was more of a melt-in-your-mouth experience). ~
#
# label	: FOOD|FOOD
# term	: food|food|budget|selection|pork|belly|experience
# pred	: FOOD|FOOD|VALUE|VALUE|FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# traditional french decour was pleasant though the hall was rather noisy - the restaurant was full and we had to raise our voices to be able to maintain a conversation. ~
#
# label	: AMBIENCE|AMBIENCE
# term	: decour|hall|restaurant|voices|conversation
# pred	: FOOD|AMBIENCE|AMBIENCE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# seating is always prompt, though the restaurant does fill up in the evening. ~
#
# label	: SERVICE
# term	: seating|restaurant
# pred	: VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# food is usually very good, though ocasionally i wondered about freshmess of raw vegatables in side orders. ~
#
# label	: FOOD|FOOD
# term	: food|food|freshmess|vegatables|side|orders
# pred	: FOOD|FOOD|FOOD|FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the decor is vibrant and eye-pleasing with several semi-private boths on the right side of the dining hall, which are great for a date. ~
#
# label	: AMBIENCE|AMBIENCE
# term	: decor|boths|side|hall|date
# pred	: AMBIENCE|AMBIENCE|VALUE|AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# the first time i went, and was completely taken by the live jazz band and atmosphere, i ordered the lobster cobb salad. ~
#
# label	: AMBIENCE|AMBIENCE
# term	: atmosphere|time|jazz|band|atmosphere
# pred	: AMBIENCE|VALUE|AMBIENCE|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# the food is a diamond in rough and the food is delicious and homemade with the perfect balance of herbs and tomatoes. ~
#
# label	: FOOD|FOOD
# term	: food|food|food|diamond|food|homemade|balance|herbs|tomatoes
# pred	: FOOD|FOOD|FOOD|FOOD|FOOD|FOOD|VALUE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the server was really cool and served us our food and drinks with a smile. ~
#
# label	: SERVICE
# term	: food|server|food|drinks
# pred	: FOOD|VALUE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the place's decor and hidden bathrooms made for a good laugh. ~
#
# label	: AMBIENCE|AMBIENCE
# term	: place|place|decor|bathrooms|laugh
# pred	: VALUE|VALUE|AMBIENCE|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# the entertainment was great they have shows that go on through out the dinner. ~
#
# label	: AMBIENCE
# term	: entertainment|shows|dinner
# pred	: VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the workers there also absolutely load the bagel with cream cheese (gets a little messy). ~
#
# label	: FOOD
# term	: workers|bagel|cream|cheese
# pred	: VALUE|FOOD|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# this was my frist time at cafe st. bart's and i must say how delicous the food and the service was. ~
#
# label	: FOOD|SERVICE
# term	: food|service|frist|time|cafe|food|service
# pred	: FOOD|VALUE|FOOD|VALUE|AMBIENCE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# i have to highly recommend the lobster roll - not to much mayo; you can tell it was a fresh lobster. ~
#
# label	: FOOD|FOOD
# term	: high|roll|mayo
# pred	: VALUE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# other guests enjoyed pizza, santa fe chopped salad and fish and chips. ~
#
# label	: FOOD|FOOD|FOOD
# term	: pizza|guests|pizza|santa|fish|chips
# pred	: FOOD|VALUE|FOOD|FOOD|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# i highly recommend cafe st. bart's for their food, the ambience and wonderful service. ~
#
# label	: FOOD|AMBIENCE|SERVICE
# term	: food|high|service|cafe|food|ambience|service
# pred	: FOOD|VALUE|SERVICE|AMBIENCE|FOOD|AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# the staff is absolutely professional!! ~
#
# label	: SERVICE
# term	: staff
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# it's boring on the inside, and our sushi was pretty below average... the tuna was soggy and the other rolls had no flavor. ~
#
# label	: FOOD|FOOD|FOOD
# term	: inside|sushi|average|tuna|rolls|flavor
# pred	: FOOD|FOOD|VALUE|FOOD|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# their pad penang is delicious and everything else is fantastic. ~
#
# label	: FOOD
# term	: penang|everything
# pred	: AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# the price is reasonable although the service is poor. ~
#
# label	: SERVICE
# term	: price|service|price|service
# pred	: VALUE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# great vibe, lots of people. ~
#
# label	: AMBIENCE
# term	: vibe|lots|people
# pred	: FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# ambience is so cute and quaint, good for business although we were there on vacation. ~
#
# label	: AMBIENCE
# term	: ambience|business|vacation
# pred	: AMBIENCE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# they have it all -- great price, food, and service. ~
#
# label	: FOOD|SERVICE
# term	: price|food|service|price|food|service
# pred	: VALUE|FOOD|SERVICE|VALUE|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# the atmosphere is noisy and the waiters are literally walking around doing things as fast as they can. ~
#
# label	: AMBIENCE|SERVICE
# term	: atmosphere|atmosphere|waiters|things
# pred	: AMBIENCE|AMBIENCE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the staff was accomodating, the food was absolutely delicious and the place is lovely. ~
#
# label	: SERVICE|FOOD|AMBIENCE
# term	: place|food|staff|food|place
# pred	: VALUE|FOOD|VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# we even had a visit from the manager who wanted to make sure we were enjoying ourselves. ~
#
# label	: SERVICE
# term	: visit
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# sometimes i get bad food and bad service, sometimes i get good good and bad service. ~
#
# label	: FOOD|SERVICE|SERVICE|FOOD
# term	: food|service|service|food|service|service
# pred	: FOOD|VALUE|VALUE|FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# mine was a little burnt but still delicious with goat cheese and panchetta (raddichio was kind of bitter though). ~
#
# label	: FOOD
# term	: goat|cheese|panchetta|raddichio|kind
# pred	: FOOD|FOOD|FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# my friend got the mushroom pizza which tasted better. ~
#
# label	: FOOD
# term	: pizza|friend|mushroom|pizza
# pred	: FOOD|VALUE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# service was slow, but the people were friendly. ~
#
# label	: SERVICE|SERVICE
# term	: service|service|people
# pred	: SERVICE|SERVICE|VALUE
# _____________________________________________________________________________________________________
#
# it's a nice place to relax and have conversation. ~
#
# label	: AMBIENCE
# term	: place|place|conversation
# pred	: AMBIENCE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# this is my first time writing a review for a restaurant because the food and service was excellent. ~
#
# label	: FOOD|SERVICE
# term	: food|service|time|review|restaurant|food|service
# pred	: FOOD|VALUE|VALUE|VALUE|AMBIENCE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# i like the ambience, it's very dark and original. ~
#
# label	: AMBIENCE
# term	: ambience
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# we won't go to this place again for a good meal. ~
#
# label	: FOOD
# term	: place|place|meal
# pred	: VALUE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# however, i think this place is a good hang out spot. ~
#
# label	: AMBIENCE
# term	: place|place|spot
# pred	: VALUE|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# the pizza and wine were excellent-the service too--but what really made this place was the backyard dining area. ~
#
# label	: FOOD|FOOD|SERVICE|AMBIENCE
# term	: place|pizza|service|pizza|wine|service|place|backyard|area
# pred	: AMBIENCE|FOOD|VALUE|FOOD|FOOD|VALUE|AMBIENCE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# it is one the nicest outdoor restaurants i have ever seen in ny--i am from italy and this place rivals the ones in my country. ~
#
# label	: AMBIENCE
# term	: place|restaurants|place|ones|country
# pred	: VALUE|AMBIENCE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# first of all, this place is *not* romantic, as claimed by citysearch's editorial review. ~
#
# label	: AMBIENCE
# term	: place|place|editorial|review
# pred	: VALUE|VALUE|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# somehow working the italian charm with constant mille grazie does not constitute proper service. ~
#
# label	: SERVICE
# term	: service|grazie|service
# pred	: SERVICE|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# fish was overdone. ~
#
# label	: FOOD
# term	: fish
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# someone else recommended the dessert - we also left that. ~
#
# label	: FOOD
# term	: someone|dessert
# pred	: VALUE|FOOD
# _____________________________________________________________________________________________________
#
# i come from a family of pizzeria owners, and i'm almost ashamed to say that the pizza in fornino's blows my families receipies away. ~
#
# label	: FOOD
# term	: pizza|family|pizzeria|owners|pizza|fornino|blows|families|receipies
# pred	: FOOD|FOOD|FOOD|VALUE|FOOD|AMBIENCE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# a restaurant that doesn't try to do anything except serve great food with great service in a pleasant atmosphere. ~
#
# label	: FOOD|SERVICE|AMBIENCE
# term	: atmosphere|food|service|restaurant|anything|food|service|atmosphere
# pred	: AMBIENCE|FOOD|VALUE|AMBIENCE|VALUE|FOOD|VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# no gimmicks here -- the food speaks for itself in its freshness and preparation. ~
#
# label	: FOOD
# term	: food|food|freshness|preparation
# pred	: FOOD|FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the service was impeccable and unobtrusive -- the staff knows what they are there to do -- to know their menu, present your meal, and attend to your needs. ~
#
# label	: SERVICE|SERVICE
# term	: service|service|staff|meal|needs
# pred	: SERVICE|SERVICE|VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the view is breathtaking the service is top notch... the ambiance is wonderfull. ~
#
# label	: AMBIENCE|SERVICE|AMBIENCE
# term	: service|view|service|notch|ambiance|wonderfull
# pred	: SERVICE|VALUE|SERVICE|AMBIENCE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# the staff offers impeccable service. ~
#
# label	: SERVICE
# term	: service|staff|service
# pred	: SERVICE|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# my boyfriend had the new england chowder it was good but i think the award should go to the lobster bisque. ~
#
# label	: FOOD|FOOD
# term	: boyfriend|chowder|bisque
# pred	: VALUE|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# my boyfriend had prime rib it was good . ~
#
# label	: FOOD
# term	: boyfriend
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# my wife and i ate here earlier this week and have not stopped ranting and raving about the food. ~
#
# label	: FOOD
# term	: food|wife|food
# pred	: FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# go to volare for 1st class service and terrific food. ~
#
# label	: SERVICE|FOOD
# term	: food|service|class|service|food
# pred	: FOOD|SERVICE|VALUE|SERVICE|FOOD
# _____________________________________________________________________________________________________
#
# the portions are large and the servers always surprise us with a different starter. ~
#
# label	: FOOD
# term	: portions|servers
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# our family never expected such incredible entertainment in a restaurant. ~
#
# label	: AMBIENCE
# term	: family|entertainment|restaurant
# pred	: VALUE|VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# and really large portions. ~
#
# label	: FOOD
# term	: portions
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the staff was the friendliest that have seen in new york. ~
#
# label	: SERVICE
# term	: staff
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the food was pretty tradional but it was hot and good with large portions. ~
#
# label	: FOOD|FOOD
# term	: food|food|portions
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the place is a lot of fun. ~
#
# label	: AMBIENCE
# term	: place|place
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# delivery is fast too. ~
#
# label	: SERVICE
# term	: delivery
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# ess-a-bagel (either by sty-town or midtown) is by far the best bagel in ny. ~
#
# label	: FOOD
# term	: ess-a-bagel|midtown|bagel
# pred	: VALUE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# the bagels always warm, soft on the inside, crispy on the outside and enormous in size. ~
#
# label	: FOOD|FOOD
# term	: bagels|inside|size
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# they have a huge selection of different cream cheeses and all of their salads are great. ~
#
# label	: FOOD|FOOD
# term	: selection|cream|cheeses|salads
# pred	: VALUE|FOOD|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# thius is a must for anyone who loves shabu-shabu. ~
#
# label	: FOOD
# term	: thius|anyone|shabu-shabu
# pred	: AMBIENCE|VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# the atmosphere is nothing special, but it feels like a sushi establishment in tokyo. ~
#
# label	: AMBIENCE
# term	: atmosphere|atmosphere|nothing|sushi|establishment
# pred	: AMBIENCE|AMBIENCE|VALUE|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# despite a slightly limited menu, everything prepared is done to perfection, ultra fresh and a work of food art. ~
#
# label	: FOOD
# term	: food|everything|ultra|food
# pred	: FOOD|VALUE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the prices were cheap compared to the quality of service and food. ~
#
# label	: SERVICE|FOOD
# term	: price|food|service|prices|quality|service|food
# pred	: VALUE|FOOD|VALUE|VALUE|VALUE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# the quantity is also very good, you will come out satisfied. ~
#
# label	: FOOD
# term	: quantity
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the wine the service was very good too. ~
#
# label	: FOOD|SERVICE
# term	: service|wine|service
# pred	: VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# i found the food, service and value exceptional everytime i have been there. ~
#
# label	: FOOD|SERVICE
# term	: value|food|service|food|service|value|everytime
# pred	: VALUE|FOOD|SERVICE|FOOD|SERVICE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# who has room for cheesesticks with the best pizza in nyc! ~
#
# label	: FOOD
# term	: pizza|room|cheesesticks|pizza
# pred	: FOOD|VALUE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# always great service! ~
#
# label	: SERVICE
# term	: service|service
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# but the staff was so horrible to us. ~
#
# label	: SERVICE
# term	: staff
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the hostess and the waitress were incredibly rude and did everything they could to rush us out. ~
#
# label	: SERVICE|SERVICE
# term	: everything
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# don't dine at tamarind for the vegetarian dishes, they are simply not up to par with the non-veg selections. ~
#
# label	: FOOD|FOOD
# term	: tamarind|dishes|selections
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# decor is nice though service can be spotty. ~
#
# label	: AMBIENCE|SERVICE
# term	: service|decor|service
# pred	: VALUE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# and yes dal bukhara is so dam good and so are all the kababs. ~
#
# label	: FOOD|FOOD
# term	: kababs
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# honestly the worst sushi my husband and i had in our entire lives. ~
#
# label	: FOOD
# term	: sushi|husband|lives
# pred	: FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the all-u-can-eat sushi is definitely in very poor quality. ~
#
# label	: FOOD
# term	: sushi|quality
# pred	: FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the only things u could really taste are the very salty soy sauce (even its low sodium), the vinegar-soaked rice, and the scallion on top of the fish. ~
#
# label	: FOOD|FOOD
# term	: things|sauce|sodium|rice|scallion|fish
# pred	: VALUE|FOOD|FOOD|FOOD|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# both times i was extremely dissappointed by the service, which was boarderline rude. ~
#
# label	: SERVICE
# term	: service|times|service
# pred	: VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the dinner was ok, nothing i would have again. ~
#
# label	: FOOD
# term	: dinner|nothing
# pred	: FOOD|VALUE
# _____________________________________________________________________________________________________
#
# try the pad thai, it's fabulous and their prices are so cheap! ~
#
# label	: FOOD
# term	: price|prices
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# just because it's cheap does not mean the portions are small or the food is nasty, it is great! ~
#
# label	: FOOD|FOOD
# term	: food|portions|food
# pred	: FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# eating in, the atmosphere saves it, but at your desk, it's a very disappointing experience. ~
#
# label	: AMBIENCE
# term	: atmosphere|atmosphere|desk|experience
# pred	: FOOD|FOOD|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# the seats are uncomfortable if you are sitting against the wall on wooden benches. ~
#
# label	: AMBIENCE
# term	: seats|wall|benches
# pred	: VALUE|VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# the food is tasty and portion sizes are appropriate. ~
#
# label	: FOOD|FOOD
# term	: food|food|portion|sizes
# pred	: FOOD|FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# fish is so very fresh. ~
#
# label	: FOOD
# term	: fish
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# waitstaff are very friendly. ~
#
# label	: SERVICE
# term	: waitstaff
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the service is good and ambience is good for a date or group outing. ~
#
# label	: SERVICE|AMBIENCE
# term	: service|service|ambience|date|group|outing
# pred	: SERVICE|SERVICE|AMBIENCE|VALUE|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# even though its good seafood, the prices are too high. ~
#
# label	: FOOD
# term	: price|high|seafood|prices
# pred	: VALUE|VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the food was delicious (i had a halibut special, my husband had steak), and the service was top-notch. ~
#
# label	: FOOD|FOOD|FOOD|SERVICE
# term	: food|service|food|halibut|husband|steak|service
# pred	: FOOD|VALUE|FOOD|FOOD|FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# truly the mark of an attentive waiter. ~
#
# label	: SERVICE
# term	: mark
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# we ate at this thai place following the reviews but very unhappy with the foods. ~
#
# label	: FOOD
# term	: place|food|place|reviews|foods
# pred	: AMBIENCE|FOOD|AMBIENCE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# i almost hesititate to write a review because the atmosphere was so great and i would hate for it too become to crowded. ~
#
# label	: AMBIENCE
# term	: atmosphere|hesititate|review|atmosphere
# pred	: VALUE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the wait staff is very freindly, they make it feel like you're eating in a freindly little european town. ~
#
# label	: SERVICE
# term	: wait|staff|town
# pred	: VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the service was terrible, we had to wait for everything and ask several of different people for the same thing before we were allowed to be served. ~
#
# label	: SERVICE
# term	: service|service|everything|people|thing
# pred	: SERVICE|SERVICE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# after dinner the manager grabbed my boyfriend, asked him: where are you from...maybe you dont know how things work in america...and in the end stormed away almost teareyed yelling that tips are the only thing they survive on. ~
#
# label	: SERVICE
# term	: dinner|boyfriend|things|tips|thing
# pred	: FOOD|VALUE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# we did tip, i guess the model/waitress just wanted more and complained to the manager. ~
#
# label	: SERVICE
# term	: model/waitress
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# decor is charming. ~
#
# label	: AMBIENCE
# term	: decor
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the ambience was so fun, and the prices were great, on top of the fact that the food was really tasty. ~
#
# label	: AMBIENCE|FOOD
# term	: price|food|ambience|prices|fact|food
# pred	: VALUE|FOOD|AMBIENCE|VALUE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# i would definitely recommend sea if you like thai cuisine! ~
#
# label	: FOOD
# term	: cuisine
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# i was here a few weeks back and we had the worst customer service experience at a restaurant ever. ~
#
# label	: SERVICE
# term	: service|customer|service|experience|restaurant
# pred	: SERVICE|SERVICE|SERVICE|VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# everything was wonderful; food, drinks, staff, mileau. ~
#
# label	: FOOD|FOOD|SERVICE|AMBIENCE
# term	: food|everything|food|drinks|staff|mileau
# pred	: FOOD|VALUE|FOOD|FOOD|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# if the weather is nice, try to snag an outside table. ~
#
# label	: AMBIENCE
# term	: weather|table
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the staff has been nice, but they seemed really stressed and the unisex bathroom needs to be cleaned more often. ~
#
# label	: SERVICE|AMBIENCE
# term	: staff|bathroom
# pred	: VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# from the spectacular caviar to the hospitable waitstaff, i felt like royalty and enjoyed every second of it. ~
#
# label	: FOOD|SERVICE
# term	: caviar|waitstaff|royalty
# pred	: FOOD|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# considering we were the last patrons there and it was after the closing time, the waitstaff did not rush us at all and made us feel comfortable and relaxed. ~
#
# label	: SERVICE
# term	: patrons|closing|time|waitstaff
# pred	: VALUE|VALUE|VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# i highly recommend caviar russe to anyone who wants delicious top grade caviar and fantastic service. ~
#
# label	: FOOD|SERVICE
# term	: high|service|caviar|russe|anyone|grade|caviar|service
# pred	: VALUE|SERVICE|FOOD|FOOD|VALUE|FOOD|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# fresh ingredients and everything is made to order. ~
#
# label	: FOOD
# term	: ingredients|everything|order
# pred	: FOOD|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# friendly staff that actually lets you enjoy your meal and the company you're with. ~
#
# label	: SERVICE
# term	: staff|meal|company
# pred	: VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the place was nice and calm. ~
#
# label	: AMBIENCE
# term	: place|place
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the buffet had a nice selection. ~
#
# label	: FOOD
# term	: buffet|selection
# pred	: FOOD|VALUE
# _____________________________________________________________________________________________________
#
# consequently, their burgers fell apart in their hands and made such a mess that they did'nt feel like finishing them. ~
#
# label	: FOOD
# term	: burgers|hands
# pred	: FOOD|VALUE
# _____________________________________________________________________________________________________
#
# this place is really trendi but they have forgotten about the most important part of a restaurant, the food. ~
#
# label	: FOOD|AMBIENCE
# term	: place|food|place|part|restaurant|food
# pred	: AMBIENCE|FOOD|AMBIENCE|VALUE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the last two times i ordered from here my food was soo spicy that i could barely eat it, and the spice took away from the flavor of the dish. ~
#
# label	: FOOD|FOOD
# term	: food|times|food|spicy|spice|flavor|dish
# pred	: FOOD|VALUE|FOOD|FOOD|FOOD|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# if you want good authentic thai this place is not the place to go. ~
#
# label	: FOOD
# term	: place|place|place|place
# pred	: VALUE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the back garden sitting area is very pleasant, where you can see their personal herb garden. ~
#
# label	: AMBIENCE
# term	: area|herb
# pred	: VALUE|FOOD
# _____________________________________________________________________________________________________
#
# my husband said he could've eaten several more, the portion was fine for me he even exclaimed that the french fries were the best he has had. ~
#
# label	: FOOD|FOOD
# term	: husband|portion|fries
# pred	: VALUE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# it's the only place you can get yummy authentic japanese comfort food. ~
#
# label	: FOOD
# term	: place|food|place|food
# pred	: VALUE|FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# great food, good size menu, great service and an unpretensious setting. ~
#
# label	: FOOD|FOOD|SERVICE|AMBIENCE
# term	: food|service|food|size|service|setting
# pred	: FOOD|SERVICE|FOOD|VALUE|SERVICE|SERVICE
# _____________________________________________________________________________________________________
#
# the freshest, best variety, and the fastest delivery. ~
#
# label	: SERVICE
# term	: delivery
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# average to good thai food, but terrible delivery. ~
#
# label	: FOOD|SERVICE
# term	: food|food|delivery
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# an excellent service ~
#
# label	: SERVICE
# term	: service|service
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# she was very helpful in suggesting us drinks and helped us in ordering a lot of good dishes since we knew nothing about indian food. ~
#
# label	: FOOD
# term	: food|drinks|dishes|nothing|food
# pred	: FOOD|FOOD|FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# we ended our great experience by having gulab jamun (dessert) recommended by the waiter. ~
#
# label	: FOOD
# term	: experience|dessert
# pred	: VALUE|FOOD
# _____________________________________________________________________________________________________
#
# the crust is thin, the ingredients are fresh and the staff is friendly. ~
#
# label	: FOOD|SERVICE|FOOD
# term	: crust|ingredients|staff
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# all of the pizzas are terrific and the price is even better! ~
#
# label	: FOOD
# term	: price|pizza|pizzas|price
# pred	: VALUE|FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# i highly recommend the sophia pizza. ~
#
# label	: FOOD
# term	: pizza|high|sophia|pizza
# pred	: FOOD|VALUE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# for the people who want great food plus great service, roxy is a place to avoid! ~
#
# label	: FOOD|SERVICE
# term	: place|food|service|people|food|service|place
# pred	: VALUE|FOOD|VALUE|VALUE|FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the first time the sushi was outstanding, the second time it was a little bland. ~
#
# label	: FOOD|FOOD
# term	: time|sushi|time
# pred	: VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the blond wood decor is very soothing, the premium sake is excellent and the service is great. ~
#
# label	: AMBIENCE|FOOD|SERVICE
# term	: service|wood|decor|premium|sake|service
# pred	: SERVICE|AMBIENCE|AMBIENCE|VALUE|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# mizu is home to creative and unique rolls not to found anywhere else. ~
#
# label	: FOOD
# term	: home|rolls
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# not only is the cuisine the best around, the service has always been attentive and charming. ~
#
# label	: FOOD|SERVICE
# term	: service|cuisine|service
# pred	: VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the view is spectacular, and the food is great. ~
#
# label	: AMBIENCE|FOOD
# term	: food|view|food
# pred	: FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# kind, attentive wait staff. ~
#
# label	: SERVICE
# term	: wait|staff
# pred	: VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# the atmosphere is unheralded, the service impecible, and the food magnificant. ~
#
# label	: AMBIENCE|SERVICE|FOOD
# term	: atmosphere|food|service|atmosphere|service|impecible|food
# pred	: AMBIENCE|FOOD|VALUE|AMBIENCE|VALUE|VALUE|FOOD
# ...
# _____________________________________________________________________________________________________
#
# the anti-pasta was excellent, especially the calamari, as were the filling pasta mains. ~
#
# label	: FOOD|FOOD|FOOD|FOOD
# term	: anti-pasta|calamari|pasta|mains
# pred	: FOOD|FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# great food, great decor, great service. ~
#
# label	: FOOD|AMBIENCE|SERVICE
# term	: food|service|food|decor|service
# pred	: FOOD|SERVICE|FOOD|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# the only thing more wonderful than the food (which is exceptional) is the service. ~
#
# label	: FOOD|SERVICE
# term	: food|service|thing|food|service
# pred	: FOOD|SERVICE|VALUE|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# cozy romantic atomosphere with only around 15 tables at most. ~
#
# label	: AMBIENCE
# term	: atomosphere|tables
# pred	: AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# too bad the food wasn't of the same heritage. ~
#
# label	: FOOD
# term	: food|food|heritage
# pred	: FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# when you're sitting in their main dining room (which has a spectacular, hand-painted high ceiling) you'd never know there was a world outside. ~
#
# label	: AMBIENCE|AMBIENCE
# term	: high|room|ceiling|world|outside
# pred	: AMBIENCE|AMBIENCE|AMBIENCE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# while the ambiance and atmosphere were great, the food and service could have been a lot better. ~
#
# label	: AMBIENCE|AMBIENCE|FOOD|SERVICE
# term	: atmosphere|food|service|ambiance|atmosphere|food|service
# pred	: AMBIENCE|FOOD|VALUE|VALUE|AMBIENCE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# i've been to sapphire twice and both times the food was fine, if not good. ~
#
# label	: FOOD
# term	: food|times|food
# pred	: FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# service is friendly, and never had a problem walking in and getting a table. ~
#
# label	: SERVICE
# term	: service|service|table
# pred	: SERVICE|SERVICE|VALUE
# _____________________________________________________________________________________________________
#
# ravioli was good...but i have to say that i found everything a bit overpriced. ~
#
# label	: FOOD
# term	: ravioli|everything
# pred	: FOOD|VALUE
# _____________________________________________________________________________________________________
#
# service, however, was excellent...and i liked the setting/atmosphere a lot. ~
#
# label	: SERVICE|AMBIENCE
# term	: service|service|setting/atmosphere
# pred	: SERVICE|SERVICE|VALUE
# _____________________________________________________________________________________________________
#
# people are always friendly. ~
#
# label	: SERVICE
# term	: people
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the design and atmosphere is just as good. ~
#
# label	: AMBIENCE|AMBIENCE
# term	: atmosphere|design|atmosphere
# pred	: VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# nice atmosphere, the service was very pleasant and the desert was good. ~
#
# label	: AMBIENCE|SERVICE|FOOD
# term	: atmosphere|service|atmosphere|service
# pred	: AMBIENCE|VALUE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# i really recommend the very simple unda (egg) rolls. ~
#
# label	: FOOD
# term	: unda|rolls
# pred	: AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# toons has recently been redone, so it's now a very attractive space. ~
#
# label	: AMBIENCE
# term	: toons|redone|space
# pred	: VALUE|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# in an area sadly lacking in decent thai food, this is one of the best spots. ~
#
# label	: FOOD
# term	: food|area|food|spots
# pred	: FOOD|VALUE|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# went here last night - nice decor, good service, but the food was surprisingly excellent. ~
#
# label	: AMBIENCE|SERVICE|FOOD
# term	: food|service|decor|service|food
# pred	: FOOD|VALUE|VALUE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# we recently decided to try this location, and to our delight, they have outdoor seating, perfect since i had my yorkie with me. ~
#
# label	: AMBIENCE
# term	: location|seating|yorkie
# pred	: VALUE|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# the portion sizes here are huge, and the sushi is good. ~
#
# label	: FOOD|FOOD
# term	: portion|sizes|sushi
# pred	: VALUE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# staff is very accomodating. ~
#
# label	: SERVICE
# term	: staff
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the portions are small but being that the food was so good makes up for that. ~
#
# label	: FOOD|FOOD
# term	: food|portions|food
# pred	: FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# the staff there is very attentive and down to earth. ~
#
# label	: SERVICE
# term	: staff|earth
# pred	: VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# great indian food and the service is incredible. ~
#
# label	: FOOD|SERVICE
# term	: food|service|food|service
# pred	: FOOD|VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# great food and the prices are very reasonable. ~
#
# label	: FOOD
# term	: price|food|food|prices
# pred	: VALUE|FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# the food here does a great service to the name (cantonese that is...). ~
#
# label	: FOOD
# term	: food|service|food|service|name|cantonese
# pred	: FOOD|SERVICE|FOOD|SERVICE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# good music, great food, speedy service affordable prices. ~
#
# label	: AMBIENCE|FOOD|SERVICE
# term	: price|food|service|music|food|service|prices
# pred	: VALUE|FOOD|VALUE|VALUE|FOOD|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# always good drinks and service is pretty good; ~
#
# label	: FOOD|SERVICE
# term	: service|drinks|service
# pred	: VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# we were seated outside and the waiter spilled red wine and hot tea on myself and my date. ~
#
# label	: SERVICE
# term	: wine|date
# pred	: FOOD|VALUE
# _____________________________________________________________________________________________________
#
# one would think we'd get an apology or complimentary drinks - instead, we got a snobby waiter wouldn't even take our order for 15 minutes and gave us lip when we asked him to do so. ~
#
# label	: SERVICE
# term	: apology|drinks|order
# pred	: VALUE|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# he offers subpar service and has no personality. ~
#
# label	: SERVICE
# term	: service|service|personality
# pred	: VALUE|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# there is no excuse for such lousy service! ~
#
# label	: SERVICE
# term	: service|service
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# most of the servers are very attentive, friendly and quite attractive. ~
#
# label	: SERVICE
# term	: servers
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the vibe is very relaxed and cozy, service was great and the food was excellent! ~
#
# label	: AMBIENCE|SERVICE|FOOD
# term	: food|service|vibe|service|food
# pred	: FOOD|VALUE|AMBIENCE|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# i would highly recommend requesting a table by the window. ~
#
# label	: AMBIENCE
# term	: high|table|window
# pred	: VALUE|VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# although they do the typical what kind of water would you like questions the service was good and overall very relaxing to place to eat. ~
#
# label	: SERVICE|AMBIENCE
# term	: place|service|kind|water|questions|service
# pred	: VALUE|SERVICE|VALUE|FOOD|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# personal pans are the perfect size for those hungry nights. ~
#
# label	: FOOD
# term	: pans|size
# pred	: FOOD|VALUE
# _____________________________________________________________________________________________________
#
# there is a downside if you're ordering in -- the delivery guys have major attitude. ~
#
# label	: SERVICE
# term	: delivery|guys|attitude
# pred	: VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# never have i had such dramatic delivery guys (a lot of huffing and panting and muttering under breath b/c i live in a walkup) who always seem disappointed with their tips. ~
#
# label	: SERVICE
# term	: delivery|guys|huffing|panting|breath|walkup|tips
# pred	: VALUE|VALUE|VALUE|VALUE|VALUE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# love the scene first off- the place has a character and nice light to it..very fortunate, location wise. ~
#
# label	: AMBIENCE|AMBIENCE|AMBIENCE
# term	: place|scene|place|character|light
# pred	: VALUE|AMBIENCE|VALUE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# we were 4 and got the family size penne a la vodka which was tremendously gigantic portion...a bucket of food literally. ~
#
# label	: FOOD
# term	: food|family|size|penne|vodka|portion|bucket|food
# pred	: FOOD|FOOD|VALUE|FOOD|FOOD|AMBIENCE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the pasta penne was pretty extra buttery, creamy which means a big task to diggest.. tasty at first but i would say that i was full with a slice of pizza and 7 to count, penne...got a little moody afterwards cause was stuffed...lol ~
#
# label	: FOOD|FOOD
# term	: pizza|pasta|penne|buttery|task
# pred	: FOOD|FOOD|FOOD|FOOD|VALUE
# _____________________________________________________________________________________________________
#
# interesting selection, good wines, service fine, fun decor. ~
#
# label	: FOOD|SERVICE|AMBIENCE|FOOD
# term	: service|selection|wines|service|decor
# pred	: VALUE|VALUE|FOOD|VALUE|AMBIENCE
# _____________________________________________________________________________________________________
#
# i have been coming here for years and have nothing but good things to say about the service and the great staff at la lanterna. ~
#
# label	: SERVICE|SERVICE
# term	: service|nothing|things|service|staff
# pred	: SERVICE|VALUE|VALUE|SERVICE|VALUE
# _____________________________________________________________________________________________________
#
# over the years the host, vittorio, and his crew, have always treated me as family--although with all the business this not-so-little gem does, it amazing he's even able to remember a consistent but not-so-frequent visitor. ~
#
# label	: SERVICE|SERVICE
# term	: crew|family|business|visitor
# pred	: AMBIENCE|AMBIENCE|VALUE|SERVICE
# _____________________________________________________________________________________________________
#
# i've also been amazed at all the new additions in the past few years: a new jazz bar, the most fantastic dining garden, the best thin crust pizzas, and now a lasagna menu which is to die for (these are not your average lasagnas)! ~
#
# label	: AMBIENCE|AMBIENCE|FOOD|FOOD
# term	: pizza|additions|jazz|crust|pizzas|lasagnas
# pred	: FOOD|VALUE|FOOD|FOOD|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# nice view of river and nyc. ~
#
# label	: AMBIENCE
# term	: view
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# very reliable place to eat ~
#
# label	: AMBIENCE
# term	: place|place
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# perfect location for those traveling in/out of the city by auto or bus ~
#
# label	: AMBIENCE
# term	: location|in/out|auto
# pred	: VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the 8th ave location was very convenient and while busy, wasn't packed ~
#
# label	: AMBIENCE
# term	: location
# pred	: VALUE
# _____________________________________________________________________________________________________
#
# the location in the heart of manhattan adjacent to the port authority makes this an easy spot to grab a bite to eat ~
#
# label	: AMBIENCE
# term	: location|heart|spot|bite
# pred	: VALUE|VALUE|AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# nice environment with a wide choice of beers ~
#
# label	: AMBIENCE
# term	: environment|choice|beers
# pred	: FOOD|VALUE|FOOD
# _____________________________________________________________________________________________________
#
# it's in a great location with windows that open out onto the pavement in nice weather. ~
#
# label	: AMBIENCE
# term	: location|windows|pavement|weather
# pred	: VALUE|AMBIENCE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# location is convienient to businesses, hotels and theaters ~
#
# label	: AMBIENCE
# term	: location|businesses|hotels|theaters
# pred	: VALUE|VALUE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# this small place has an amazing atmosphere of energy and yet intimacy ~
#
# label	: AMBIENCE
# term	: atmosphere|place|place|atmosphere|energy
# pred	: AMBIENCE|AMBIENCE|AMBIENCE|AMBIENCE|VALUE
# _____________________________________________________________________________________________________
#
# this is probably the worst place in total experience value in new york city ~
#
# label	: AMBIENCE
# term	: place|value|place|experience|value
# pred	: VALUE|VALUE|VALUE|VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the atmosphere was amazing! ~
#
# label	: AMBIENCE
# term	: atmosphere|atmosphere
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# the atmosphere was amazing! ~
#
# label	: AMBIENCE
# term	: atmosphere|atmosphere
# pred	: VALUE|VALUE
# _____________________________________________________________________________________________________
#
# 128 297 260 14 0.32989690721649484 0.9014084507042254 0.48301886792452825
# (128,
#  297,
#  260,
#  14,
#  0.32989690721649484,
#  0.9014084507042254,
#  0.48301886792452825)
