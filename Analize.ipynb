# %%
# import pandas as pd
# df = pd.read_csv('dataset/restaurant-multiple-categories.csv')
# df.to_excel('dataset/restaurant.xlsx')

# %%
import pandas as pd

def analize(label, tipe, positif):
    df = pd.read_csv('Results/Categorization/'+ tipe +'.csv')
    
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    kosong = 0
    
    for index in range(0, len(df)):
        labels = df['label'][index].split(',')
        
        if type(df['predict'][index]) != float:
            preds = df['predict'][index].split('|')

            if label in labels and label in preds:
                tp += 1
            elif label not in labels and label not in preds:
                tn += 1
            elif label not in labels and label in preds:
                if positif:
                    print(df['review'][index], '~')
                    print()
                    print('label\t:', df['label'][index])
                    print('target\t:', df['target'][index])
                    print('term\t:', df['term'][index])
#                     error = []
#                     for i, aspek in enumerate(df['pred_multiple'][index].split('|')):
#                         if aspek == label:
#                             error.append(df['terms'][index].split('|')[i])
#                     print(' | '.join(error))
                    print('pred\t:', df['predict'][index])
                    print('_____________________________________________________________________________________________________')
                    print()
                fp += 1
            elif label in labels and label not in preds:
                if not positif:
                    print(df['review'][index], '~')
                    print()
                    print('label\t:', df['label'][index])
                    print('target\t:', df['target'][index])
                    print('term\t:', df['term'][index])
#                     error = []
#                     for i, aspek in enumerate(df['pred_multiple'][index].split('|')):
#                         if aspek != label:
#                             error.append(df['terms'][index].split('|')[i])
#                     print(' | '.join(error))
                    print('pred\t:', df['predict'][index])
                    print('_____________________________________________________________________________________________________')
                    print()
                fn += 1
        elif label in labels:
            fn += 1
            if not positif:
                print(df['review'][index], '~')
                print()
                print('label\t:', df['label'][index])
                print('target\t:', df['target'][index])
                print('---')
                print('')
        else:
            tn += 1
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1 = 2 * ((precision * recall) / (precision + recall))
    print(tp, tn, fp, fn, precision, recall, f1)
    return tp, tn, fp, fn, precision, recall, f1

# %%
import pandas as pd

analize("AMBIENCE", 'plsa-partial-ner', True)
# Out:
# we, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude. ~
#
# label	: SERVICE
# target	: staff
# term	: staff|place|like
# pred	: SERVICE|AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# i have eaten at saul, many times, the food is always consistently, outrageously good. ~
#
# label	: FOOD
# target	: food
# term	: food|good|always
# pred	: FOOD|AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# food was okay, nothing great. ~
#
# label	: FOOD
# target	: Food
# term	: food|great
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# the kitchen however, is almost always slow. ~
#
# label	: SERVICE
# target	: kitchen
# term	: always
# pred	: AMBIENCE
# _____________________________________________________________________________________________________
#
# add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening. ~
#
# label	: SERVICE,FOOD,PRICES
# target	: service,food,food
# term	: food|price|service|great|great|great|reasonable|even
# pred	: FOOD|PRICES|SERVICE|FOOD|FOOD|FOOD|PRICES|AMBIENCE
# _____________________________________________________________________________________________________
#
# the hostess is rude to the point of being offensive. ~
#
# label	: SERVICE
# target	: hostess
# term	: point
# pred	: AMBIENCE
# _____________________________________________________________________________________________________
#
# we have been to this place many times, and always have great food, wine, and service. ~
#
# label	: FOOD,FOOD,SERVICE
# target	: food,wine,service
# term	: food|service|great|place|always|wine
# pred	: FOOD|SERVICE|FOOD|AMBIENCE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# we were worried we would have trouble getting in, but somehow managed to have a short wait. ~
#
# label	: SERVICE
# target	: wait
# term	: wait|would
# pred	: AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# as always we had a great glass of wine while we waited. ~
#
# label	: FOOD
# target	: glass of wine
# term	: great|wait|always|wine
# pred	: FOOD|AMBIENCE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the people that work there are always so friendly you forget you are in new york sometimes. ~
#
# label	: SERVICE
# target	: people
# term	: friendly|always
# pred	: SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# service was prompt, friendly and great. ~
#
# label	: SERVICE
# target	: Service
# term	: service|great|friendly
# pred	: SERVICE|AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# our server was very helpful and friendly. ~
#
# label	: SERVICE
# target	: server
# term	: friendly
# pred	: AMBIENCE
# _____________________________________________________________________________________________________
#
# the tuna and wasabe potatoes are excellent. ~
#
# label	: FOOD,FOOD
# target	: tuna,wasabe potatoes
# term	: excellent
# pred	: AMBIENCE
# _____________________________________________________________________________________________________
#
# service was very good - prompt, attentive and non-intrusive. ~
#
# label	: SERVICE
# target	: Service
# term	: good|service
# pred	: AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# seating is always prompt, though the restaurant does fill up in the evening. ~
#
# label	: SERVICE
# target	: Seating
# term	: restaurant|always|though|even
# pred	: FOOD|FOOD|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# the server was really cool and served us our food and drinks with a smile. ~
#
# label	: SERVICE
# target	: server
# term	: food|really
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# the service was the only thing good about this restaurant. ~
#
# label	: SERVICE
# target	: service,restaurant
# term	: good|service|restaurant
# pred	: AMBIENCE|SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# hats off to the chef. ~
#
# label	: FOOD
# target	: chef
# term	: hats
# pred	: AMBIENCE
# _____________________________________________________________________________________________________
#
# although we were looking for regular lettuce and some walnuts the salads we got were great. ~
#
# label	: FOOD
# target	: salads
# term	: great|though
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# we even had a visit from the manager who wanted to make sure we were enjoying ourselves. ~
#
# label	: SERVICE
# target	: Manager
# term	: make|even
# pred	: AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# mine was a little burnt but still delicious with goat cheese and panchetta (raddichio was kind of bitter though). ~
#
# label	: FOOD,FOOD
# target	: raddichio,NULL
# term	: delicious|though
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# service was slow, but the people were friendly. ~
#
# label	: SERVICE,SERVICE
# target	: Service,people
# term	: service|friendly
# pred	: SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# this is my first time writing a review for a restaurant because the food and service was excellent. ~
#
# label	: FOOD,SERVICE
# target	: food,service
# term	: food|service|restaurant|excellent
# pred	: FOOD|SERVICE|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# we won't go to this place again for a good meal. ~
#
# label	: FOOD
# target	: meal
# term	: good|place|meal
# pred	: FOOD|AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# someone else recommended the dessert - we also left that. ~
#
# label	: FOOD
# target	: dessert
# term	: someone|dessert
# pred	: AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# one of us actually liked the expresso - that's it. ~
#
# label	: FOOD
# target	: expresso
# term	: like
# pred	: AMBIENCE
# _____________________________________________________________________________________________________
#
# the food can get pricey but the prixe fixe tasting menu is the greatest food for a good price and they cater the food to any food allergies or food you don't like. ~
#
# label	: PRICES,FOOD,PRICES,SERVICE
# target	: food,prixe fixe tasting menu,prixe fixe tasting menu,NULL
# term	: food|food|food|food|food|price|price|good|great|like|menu
# pred	: FOOD|FOOD|FOOD|FOOD|FOOD|FOOD|FOOD|FOOD|FOOD|AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# service was slow had to wait to order and get food although not crowded. ~
#
# label	: SERVICE
# target	: Service
# term	: food|service|wait|though
# pred	: FOOD|SERVICE|SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# the service was excellent - friendly and attentive. ~
#
# label	: SERVICE
# target	: service
# term	: service|friendly|excellent
# pred	: SERVICE|SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# great staff. ~
#
# label	: SERVICE
# target	: staff
# term	: staff|great
# pred	: SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# always great service! ~
#
# label	: SERVICE
# target	: service
# term	: service|great|always
# pred	: PRICES|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# this place is pricey, and yes, the food is worth it; but the service makes you feel like you should be paying a quater of the price. ~
#
# label	: PRICES,FOOD,SERVICE
# target	: place,food,service
# term	: food|price|price|service|place|like|make|worth
# pred	: FOOD|PRICES|PRICES|SERVICE|AMBIENCE|PRICES|FOOD|PRICES
# _____________________________________________________________________________________________________
#
# the waitstaffs are nice though. ~
#
# label	: SERVICE
# target	: waitstaffs
# term	: nice|staff|wait|though
# pred	: FOOD|SERVICE|SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# waitstaff are very friendly. ~
#
# label	: SERVICE
# target	: Waitstaff
# term	: staff|friendly|wait
# pred	: SERVICE|AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# even though its good seafood, the prices are too high. ~
#
# label	: FOOD,PRICES
# target	: seafood,seafood
# term	: food|price|good|though|even
# pred	: FOOD|PRICES|FOOD|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# i like cafe noir dont get me wrong, it is jsut that the people who work there are evil and incompetent!! ~
#
# label	: SERVICE
# target	: people,Cafe Noir
# term	: like
# pred	: AMBIENCE
# _____________________________________________________________________________________________________
#
# the whole set up is truly unprofessional and i wish cafe noir would get some good staff, because despite the current one this is a great place. ~
#
# label	: SERVICE
# target	: staff,Cafe Noir
# term	: good|staff|great|place|would
# pred	: SERVICE|SERVICE|AMBIENCE|AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# a gentleman, maybe the manager, came to our table, and without so much as a smile or greeting asked for our order. ~
#
# label	: SERVICE
# target	: gentleman
# term	: gentleman|table|smile|order
# pred	: SERVICE|SERVICE|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# service was also very good. ~
#
# label	: SERVICE
# target	: Service
# term	: good|service
# pred	: AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# this is a wonderful place on all stand points especially value ofr money. ~
#
# label	: PRICES
# target	: place,place
# term	: place|special
# pred	: AMBIENCE|PRICES
# _____________________________________________________________________________________________________
#
# all of the pizzas are terrific and the price is even better! ~
#
# label	: FOOD,PRICES
# target	: pizzas,pizzas
# term	: price|pizza|even
# pred	: PRICES|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# this place is not worth the prices. ~
#
# label	: PRICES
# target	: place,place
# term	: price|place|worth
# pred	: PRICES|AMBIENCE|PRICES
# _____________________________________________________________________________________________________
#
# i cannot imagine a friendlier staff working in a restaurant. ~
#
# label	: SERVICE
# target	: staff
# term	: restaurant|staff
# pred	: AMBIENCE|SERVICE
# _____________________________________________________________________________________________________
#
# the rest of the dim sum, though pricey by chinatown standards, is worth it. ~
#
# label	: PRICES,FOOD
# target	: dim sum,dim sum
# term	: price|though|worth
# pred	: PRICES|AMBIENCE|PRICES
# _____________________________________________________________________________________________________
#
# this place would be so much better served by being run by a group that actually understands customer service. ~
#
# label	: SERVICE
# target	: customer service
# term	: service|place|would
# pred	: SERVICE|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# spreads and toppings are great - though a bit pricey. ~
#
# label	: FOOD,FOOD,PRICES,PRICES
# target	: Spreads,toppings,Spreads,toppings
# term	: price|great|though
# pred	: PRICES|PRICES|AMBIENCE
# _____________________________________________________________________________________________________
#
# service is fast and friendly. ~
#
# label	: SERVICE
# target	: Service
# term	: service|friendly
# pred	: SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# if you are looking for a good quality, cheap eats - this is the place. ~
#
# label	: FOOD,PRICES
# target	: eats,eats
# term	: good|place
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# volare virgins or weekly regulars, everyone gets treated the same and you can't ask for more than that when the service is this friendly. ~
#
# label	: SERVICE
# target	: service
# term	: service|friendly
# pred	: SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# still, any quibbles about the bill were off-set by the pour-your-own measures of liquers which were courtesey of the house... ~
#
# label	: PRICES,FOOD
# target	: NULL,measures of liquers
# term	: quibbles|bill|measures|liquers|courtesey|house
# pred	: FOOD|PRICES|PRICES|FOOD|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# this little place definitely exceeded my expectations and you sure get a lot of food for your money. ~
#
# label	: FOOD,PRICES
# target	: food,place,food
# term	: food|place
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# this place is a great bargain. ~
#
# label	: PRICES
# target	: place
# term	: great|place
# pred	: PRICES|AMBIENCE
# _____________________________________________________________________________________________________
#
# bottles of wine are cheap and good. ~
#
# label	: PRICES,FOOD
# target	: bottles of wine,bottles of wine
# term	: good|wine
# pred	: AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# great food and the prices are very reasonable. ~
#
# label	: FOOD,PRICES
# target	: food,NULL
# term	: food|price|great|reasonable
# pred	: FOOD|PRICES|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# i paid just about $60 for a good meal, though :) ~
#
# label	: FOOD,PRICES
# target	: meal,meal
# term	: good|meal|though
# pred	: FOOD|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# im not necessarily fanatical about this place, but it was a fun time for low pirces. ~
#
# label	: PRICES
# target	: place,place
# term	: place
# pred	: AMBIENCE
# _____________________________________________________________________________________________________
#
# we were offered water for the table but were not told the voss bottles of water were $8 a piece. ~
#
# label	: PRICES
# target	: Voss bottles of water
# term	: water|table|voss|bottles|water|piece
# pred	: FOOD|SERVICE|FOOD|FOOD|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# great place, great value. ~
#
# label	: PRICES
# target	: place,place
# term	: great|great|place
# pred	: AMBIENCE|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# but $500 for a dinner for two that didn't include wine? ~
#
# label	: PRICES
# target	: dinner for two
# term	: wine|dinner
# pred	: AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# i read reviews that called the restaurant too expensive and i thought to myself, but may be it is worth it. ~
#
# label	: PRICES
# target	: restaurant,restaurant
# term	: restaurant|though|worth
# pred	: FOOD|AMBIENCE|PRICES
# _____________________________________________________________________________________________________
#
# i have never left a restaurant feeling as if i was abused, and wasted my hard earned money. ~
#
# label	: PRICES
# target	: restaurant,restaurant
# term	: restaurant
# pred	: AMBIENCE
# _____________________________________________________________________________________________________
#
# but if you're prepared to spend some $ and remember to ask if something they offer is complimentary, then this is the place to go for indian food ~
#
# label	: FOOD,PRICES
# target	: Indian food,place
# term	: food|place
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# too bad i had paid an extra $2 for the stone bowl. ~
#
# label	: PRICES
# target	: stone bowl
# term	: stone|bowl
# pred	: AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# maybe it was the great company (i had friends visiting from philly – yes, it was not a date this time) or the super reasonable price point, but i just can’t say enough good things about this brasserie. ~
#
# label	: PRICES
# target	: brasserie,brasserie
# term	: price|good|great|reasonable
# pred	: PRICES|FOOD|AMBIENCE|PRICES
# _____________________________________________________________________________________________________
#
# they are extremely rude, not even apologizing for the horrible service we got and handing us a bill well over $500 for some drinks adn their pita bread! ~
#
# label	: SERVICE,PRICES,PRICES,SERVICE
# target	: service,drinks,pita bread,NULL
# term	: service|even
# pred	: SERVICE|AMBIENCE
# _____________________________________________________________________________________________________
#
# at first glance this place seems a bit pricey for a hot dog joint, but at bark you don't just get your average hot dog. ~
#
# label	: PRICES,FOOD
# target	: Bark,hot dog
# term	: price|place
# pred	: PRICES|AMBIENCE
# _____________________________________________________________________________________________________
#
# 118 247 66 33 0.6413043478260869 0.7814569536423841 0.7044776119402985
# (118, 247, 66, 33, 0.6413043478260869, 0.7814569536423841, 0.7044776119402985)

# %%
import pandas as pd

# analize("FOOD", '16_baru_nan', True)
