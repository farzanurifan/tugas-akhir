# %%
# import pandas as pd
# df = pd.read_csv('dataset/restaurant-multiple-categories.csv')
# df.to_excel('dataset/restaurant.xlsx')

# %%
import pandas as pd

def analize(label, tipe, positif):
    df = pd.read_csv('Results/Categorization/'+ tipe +'.csv')
    
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    kosong = 0
    
    for index in range(0, len(df)):
        labels = df['label'][index].split(',')
        
        if type(df['predict'][index]) != float:
            preds = df['predict'][index].split('|')

            if label in labels and label in preds:
                tp += 1
            elif label not in labels and label not in preds:
                tn += 1
            elif label not in labels and label in preds:
                if positif:
                    print(df['review'][index], '~')
                    print()
                    print('label\t:', df['label'][index])
                    print('target\t:', df['target'][index])
                    print('term\t:', df['term'][index])
#                     error = []
#                     for i, aspek in enumerate(df['pred_multiple'][index].split('|')):
#                         if aspek == label:
#                             error.append(df['terms'][index].split('|')[i])
#                     print(' | '.join(error))
                    print('pred\t:', df['predict'][index])
                    print('_____________________________________________________________________________________________________')
                    print()
                fp += 1
            elif label in labels and label not in preds:
                if not positif:
                    print(df['review'][index], '~')
                    print()
                    print('label\t:', df['label'][index])
                    print('target\t:', df['target'][index])
                    print('term\t:', df['term'][index])
#                     error = []
#                     for i, aspek in enumerate(df['pred_multiple'][index].split('|')):
#                         if aspek != label:
#                             error.append(df['terms'][index].split('|')[i])
#                     print(' | '.join(error))
                    print('pred\t:', df['predict'][index])
                    print('_____________________________________________________________________________________________________')
                    print()
                fn += 1
        elif label in labels:
            fn += 1
            if not positif:
                print(df['review'][index], '~')
                print()
                print('label\t:', df['label'][index])
                print('target\t:', df['target'][index])
                print('---')
                print('')
        else:
            tn += 1
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1 = 2 * ((precision * recall) / (precision + recall))
    print(tp, tn, fp, fn, precision, recall, f1)
    return tp, tn, fp, fn, precision, recall, f1

# %%
import pandas as pd

analize("FOOD", 'lda2vec-partial-ner-elmo-money', True)
# Out:
# ive asked a cart attendant for a lotus leaf wrapped rice and she replied back rice and just walked away. ~
#
# label	: SERVICE
# target	: cart attendant
# term	: back
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# the decor is night tho...but they really need to clean that vent in the ceiling...its quite un-appetizing, and kills your effort to make this place look sleek and modern. ~
#
# label	: AMBIENCE,AMBIENCE,AMBIENCE
# target	: place,decor,vent
# term	: make|place|decor|really
# pred	: AMBIENCE|AMBIENCE|AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# ambiance- relaxed and stylish. ~
#
# label	: AMBIENCE
# target	: Ambiance
# term	: ambiance
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# i happen to have a policy that goes along with a little bit of self-respect, which includes not letting a waiter intimidate me, i.e. make me feel bad asking for trivialities like water, or the check. ~
#
# label	: SERVICE
# target	: waiter
# term	: make|feel|like|wait
# pred	: FOOD|FOOD|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# the service varys from day to day- sometimes they're very nice, and sometimes not. ~
#
# label	: SERVICE
# target	: service
# term	: service|nice
# pred	: SERVICE|FOOD
# _____________________________________________________________________________________________________
#
# the ambience is pretty and nice for conversation, so a casual lunch here would probably be best. ~
#
# label	: AMBIENCE
# target	: ambience,NULL
# term	: ambience|would|best|nice
# pred	: AMBIENCE|FOOD|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# once you step into cosette, you're miraculously in a small, off-the-beaten path parisian bistro. ~
#
# label	: AMBIENCE
# target	: Cosette
# term	: cosette|path|bistro
# pred	: FOOD|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# my wife and i always enjoy the young, not always well trained but nevertheless friendly, staff, all of whom have a story. ~
#
# label	: SERVICE
# target	: staff
# term	: never|friendly|well|always|always|staff
# pred	: AMBIENCE|SERVICE|FOOD|FOOD|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# the hostess is rude to the point of being offensive. ~
#
# label	: SERVICE
# target	: hostess
# term	: rude
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# but the pizza is way to expensive. ~
#
# label	: PRICES
# target	: pizza
# term	: pizza
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# a large is $20, and toppings are about $3 each. ~
#
# label	: PRICES,PRICES
# target	: NULL,toppings
# term	: toppings|$20!-|$3!-
# pred	: FOOD|PRICES|PRICES
# _____________________________________________________________________________________________________
#
# first went here to enjoy their garden terrace. ~
#
# label	: AMBIENCE
# target	: garden terrace
# term	: garden|terrace
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# admittedly some nights inside the restaurant were rather warm, but the open kitchen is part of the charm. ~
#
# label	: AMBIENCE,AMBIENCE
# target	: open kitchen,restaurant
# term	: restaurant
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# i'd highly recommend it for a special occasion -- it provides and intimate setting and nice service. ~
#
# label	: AMBIENCE,SERVICE
# target	: setting,service,NULL
# term	: service|nice|special
# pred	: SERVICE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# downstairs lounge is always a good attraction ~
#
# label	: AMBIENCE
# target	: Downstairs lounge
# term	: good|always
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# raga's is a romantic, cozy restaurant. ~
#
# label	: AMBIENCE
# target	: Raga's
# term	: restaurant|romantic
# pred	: AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# the waitress moved our table practically into the bathroom and when we asked to cancel our dinner orders because we did not want to eat sitting on the toilet, we were told no... ~
#
# label	: SERVICE
# target	: waitress
# term	: dinner|wait
# pred	: FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# traditional french decour was pleasant though the hall was rather noisy - the restaurant was full and we had to raise our voices to be able to maintain a conversation. ~
#
# label	: AMBIENCE,AMBIENCE
# target	: Traditional French decour,hall
# term	: though|restaurant
# pred	: AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# seating is always prompt, though the restaurant does fill up in the evening. ~
#
# label	: SERVICE
# target	: Seating
# term	: though|restaurant|always
# pred	: AMBIENCE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the server was really cool and served us our food and drinks with a smile. ~
#
# label	: SERVICE
# target	: server
# term	: food|really
# pred	: FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# the place's decor and hidden bathrooms made for a good laugh. ~
#
# label	: AMBIENCE,AMBIENCE
# target	: decor,hidden bathrooms
# term	: place|decor|good
# pred	: AMBIENCE|AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# great vibe, lots of people. ~
#
# label	: AMBIENCE
# target	: vibe
# term	: great
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# and it all comes at a very reasonable price (congee, noodles, and rice dishes are no more than $3-6 each). ~
#
# label	: PRICES,PRICES,PRICES,PRICES
# target	: NULL,congee,noodles,rice dishes
# term	: dish|reasonable|price|$3-6!-
# pred	: FOOD|PRICES|PRICES|PRICES
# _____________________________________________________________________________________________________
#
# the takeout is great too since they give high quality tupperware as well. ~
#
# label	: SERVICE
# target	: takeout
# term	: well|great
# pred	: AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# the service was impeccable and unobtrusive -- the staff knows what they are there to do -- to know their menu, present your meal, and attend to your needs. ~
#
# label	: SERVICE,SERVICE
# target	: service,staff
# term	: service|menu|staff|meal
# pred	: SERVICE|SERVICE|SERVICE|FOOD
# _____________________________________________________________________________________________________
#
# the place is small and intimate and you may feel a little crowded, but the service is excellent and it's great for friends out, a romantic date, or a special occassion. ~
#
# label	: SERVICE,AMBIENCE
# target	: service,place,place
# term	: service|place|feel|romantic|excellent|great|special
# pred	: SERVICE|AMBIENCE|AMBIENCE|FOOD|AMBIENCE|AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# service was slow had to wait to order and get food although not crowded. ~
#
# label	: SERVICE
# target	: Service
# term	: service|though|food|wait
# pred	: SERVICE|AMBIENCE|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# the atmosphere is nothing special, but it feels like a sushi establishment in tokyo. ~
#
# label	: AMBIENCE
# target	: atmosphere
# term	: atmosphere|sushi|feel|like|special
# pred	: AMBIENCE|FOOD|AMBIENCE|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# this quaint and romantic trattoria is at the top of my manhattan restaurant list. ~
#
# label	: AMBIENCE
# target	: trattoria,trattoria
# term	: restaurant|romantic
# pred	: FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the waitstaffs are nice though. ~
#
# label	: SERVICE
# target	: waitstaffs
# term	: though|nice|wait|staff
# pred	: AMBIENCE|FOOD|SERVICE|SERVICE
# _____________________________________________________________________________________________________
#
# the svc can be a bit rude at times, esp if you have big group, but overall the restaurant is a must! ~
#
# label	: SERVICE
# target	: svc,restaurant
# term	: rude|restaurant
# pred	: FOOD|FOOD
# _____________________________________________________________________________________________________
#
# it's a rather cramped and busy restaurant and it closes early. ~
#
# label	: AMBIENCE
# target	: restaurant,restaurant
# term	: restaurant
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# patroon features a nice cigar bar and has great staff. ~
#
# label	: AMBIENCE,SERVICE
# target	: cigar bar,staff
# term	: nice|great|staff
# pred	: FOOD|SERVICE|SERVICE
# _____________________________________________________________________________________________________
#
# the service is good and ambience is good for a date or group outing. ~
#
# label	: SERVICE,AMBIENCE
# target	: service,ambience
# term	: service|ambience|good|good
# pred	: SERVICE|AMBIENCE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# the only fallback on this restaurant is the prices. ~
#
# label	: PRICES
# target	: restaurant
# term	: restaurant|back|price
# pred	: FOOD|PRICES|PRICES
# _____________________________________________________________________________________________________
#
# when my dessert came, there was a candle in it - not because anyone asked for one - but because the waiter must have seen me opening my birthday card and gift, and said he knew it was a special occassion of some sort. ~
#
# label	: SERVICE
# target	: waiter
# term	: wait|special
# pred	: SERVICE|FOOD
# _____________________________________________________________________________________________________
#
# the food is so cheap and the waiters are nice. ~
#
# label	: PRICES,SERVICE
# target	: food,waiters
# term	: food|nice|wait
# pred	: FOOD|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# i almost hesititate to write a review because the atmosphere was so great and i would hate for it too become to crowded. ~
#
# label	: AMBIENCE
# target	: atmosphere
# term	: would|atmosphere|great
# pred	: FOOD|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# the wait staff is very freindly, they make it feel like you're eating in a freindly little european town. ~
#
# label	: SERVICE
# target	: wait staff
# term	: make|feel|like|wait|staff
# pred	: FOOD|AMBIENCE|SERVICE|SERVICE|SERVICE
# _____________________________________________________________________________________________________
#
# the waitress, seems to be more concerned of looking good than actually waitressing. ~
#
# label	: SERVICE
# target	: waitress
# term	: good|wait|wait
# pred	: FOOD|SERVICE|SERVICE
# _____________________________________________________________________________________________________
#
# after dinner the manager grabbed my boyfriend, asked him: where are you from...maybe you dont know how things work in america...and in the end stormed away almost teareyed yelling that tips are the only thing they survive on. ~
#
# label	: SERVICE
# target	: manager
# term	: dinner
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# we did tip, i guess the model/waitress just wanted more and complained to the manager. ~
#
# label	: SERVICE
# target	: waitress
# term	: wait
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# i was here a few weeks back and we had the worst customer service experience at a restaurant ever. ~
#
# label	: SERVICE
# target	: customer service
# term	: service|restaurant|back
# pred	: SERVICE|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# a gentleman, maybe the manager, came to our table, and without so much as a smile or greeting asked for our order. ~
#
# label	: SERVICE
# target	: gentleman
# term	: gentleman|manager|table|smile|order
# pred	: SERVICE|SERVICE|SERVICE|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# i have tried to make reservations, but both times, the hostess didn't have my name. ~
#
# label	: SERVICE
# target	: hostess
# term	: make
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# if the weather is nice, try to snag an outside table. ~
#
# label	: AMBIENCE
# target	: outside table
# term	: nice
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# the staff has been nice, but they seemed really stressed and the unisex bathroom needs to be cleaned more often. ~
#
# label	: SERVICE,SERVICE,AMBIENCE
# target	: staff,staff,unisex bathroom
# term	: really|nice|staff
# pred	: FOOD|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# friendly staff that actually lets you enjoy your meal and the company you're with. ~
#
# label	: SERVICE
# target	: staff
# term	: friendly|staff|meal
# pred	: SERVICE|SERVICE|FOOD
# _____________________________________________________________________________________________________
#
# we were greeted promptly by the waiter who was very nice and cordial. ~
#
# label	: SERVICE
# target	: waiter
# term	: nice|wait
# pred	: FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# always a nice crowd, but never loud. ~
#
# label	: AMBIENCE
# target	: crowd,NULL
# term	: never|always|nice
# pred	: AMBIENCE|AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# i asked for an open faced cheese sandwich and the manager basically told me to take my business elsewhere! ~
#
# label	: SERVICE
# target	: manager
# term	: cheese|sandwich|manager|business
# pred	: FOOD|FOOD|SERVICE|PRICES
# _____________________________________________________________________________________________________
#
# good, fast service. ~
#
# label	: SERVICE
# target	: service
# term	: service|good
# pred	: SERVICE|FOOD
# _____________________________________________________________________________________________________
#
# great atmoshere and worth every bit. ~
#
# label	: AMBIENCE
# target	: atmoshere,NULL
# term	: worth|great
# pred	: PRICES|FOOD
# _____________________________________________________________________________________________________
#
# the in-house lady dj on saturday nights has outrageously good taste in music, and moreover, takes requests. ~
#
# label	: AMBIENCE
# target	: in-house lady DJ
# term	: good
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# also it's great to have dinner in a very romantic and confortable place, the service it's just perfect...they're so frendly that we never want to live the place! ~
#
# label	: AMBIENCE,SERVICE
# target	: place,service
# term	: never|service|place|place|dinner|romantic|great
# pred	: PRICES|SERVICE|AMBIENCE|AMBIENCE|FOOD|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# cozy romantic atomosphere with only around 15 tables at most. ~
#
# label	: AMBIENCE
# target	: atomosphere
# term	: romantic
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# warm and friendly in the winter and terrific outdoor seating in the warmer months. ~
#
# label	: AMBIENCE,AMBIENCE
# target	: NULL,outdoor seating
# term	: friendly
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# toons has recently been redone, so it's now a very attractive space. ~
#
# label	: AMBIENCE
# target	: Toons
# term	: toons|redone|space
# pred	: FOOD|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# we recently decided to try this location, and to our delight, they have outdoor seating, perfect since i had my yorkie with me. ~
#
# label	: AMBIENCE
# target	: outdoor seating
# term	: location|delight|seating|yorkie
# pred	: AMBIENCE|AMBIENCE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# whoever the jazz duo was, they were on point. ~
#
# label	: AMBIENCE
# target	: jazz duo
# term	: jazz|duo|point
# pred	: FOOD|AMBIENCE|AMBIENCE
# _____________________________________________________________________________________________________
#
# with so many good restaurants on the uws, i don't need overpriced food, absurdly arrogant wait-staff who don't recognize they work at a glorified diner, clumsy service, and management that doesn't care. ~
#
# label	: PRICES,SERVICE,SERVICE,SERVICE
# target	: food,wait-staff,service,management
# term	: overpriced|service|good|restaurant|food|wait|price|staff
# pred	: FOOD|SERVICE|FOOD|FOOD|FOOD|SERVICE|FOOD|SERVICE
# _____________________________________________________________________________________________________
#
# $20 for all you can eat sushi cannot be beaten. ~
#
# label	: PRICES
# target	: all you can eat sushi
# term	: sushi|$20!-
# pred	: FOOD|PRICES
# _____________________________________________________________________________________________________
#
# it was totally overpriced- fish and chips was about $15.... ~
#
# label	: PRICES,PRICES
# target	: NULL,fish and chips
# term	: overpriced|price|$15!-
# pred	: FOOD|FOOD|PRICES
# _____________________________________________________________________________________________________
#
# great place to relax and enjoy your dinner ~
#
# label	: AMBIENCE
# target	: place
# term	: place|dinner|great
# pred	: AMBIENCE|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# i thought the restaurant was nice and clean. ~
#
# label	: AMBIENCE
# target	: restaurant,restaurant
# term	: though|restaurant|nice
# pred	: FOOD|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# overpriced japanese food with mediocre service ~
#
# label	: PRICES,SERVICE
# target	: japanese food,service
# term	: overpriced|service|food|price
# pred	: FOOD|SERVICE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# not because you are "the four seasons"... – you are allowed to charge an arm and a leg for a romatic dinner. ~
#
# label	: PRICES
# target	: The Four Seasons
# term	: dinner
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# i do not think dinner in manhattan should cost $400.00 where i am not swept off my feet. ~
#
# label	: PRICES
# target	: dinner
# term	: dinner|$400.00!-
# pred	: FOOD|PRICES
# _____________________________________________________________________________________________________
#
# we were offered water for the table but were not told the voss bottles of water were $8 a piece. ~
#
# label	: PRICES
# target	: Voss bottles of water
# term	: water|table|voss|bottles|water|piece|$8!-
# pred	: FOOD|SERVICE|FOOD|FOOD|FOOD|AMBIENCE|PRICES
# _____________________________________________________________________________________________________
#
# a beautifully designed dreamy egyptian restaurant that gets sceney at night. ~
#
# label	: AMBIENCE
# target	: Egyptian restaurant
# term	: restaurant
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# oh, and there's hookah. ~
#
# label	: AMBIENCE
# target	: hookah
# term	: hookah
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# prices are fair across the board for both food and bev. ~
#
# label	: PRICES,PRICES
# target	: food,bev
# term	: food|price
# pred	: FOOD|PRICES
# _____________________________________________________________________________________________________
#
# we were drawn into the belly dancing show that captivated the crowd. ~
#
# label	: AMBIENCE
# target	: belly dancing show
# term	: belly|dancing|crowd
# pred	: FOOD|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# helpful service and average price per dish $10. ~
#
# label	: SERVICE,PRICES
# target	: service,dish
# term	: service|dish|price|$10!-
# pred	: SERVICE|FOOD|PRICES|PRICES
# _____________________________________________________________________________________________________
#
# the only thing that strikes you is the decor?(not very pleasant). ~
#
# label	: AMBIENCE
# target	: decor
# term	: decor
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# but $500 for a dinner for two that didn't include wine? ~
#
# label	: PRICES
# target	: dinner for two
# term	: dinner|wine|$500!-
# pred	: FOOD|AMBIENCE|PRICES
# _____________________________________________________________________________________________________
#
# i read reviews that called the restaurant too expensive and i thought to myself, but may be it is worth it. ~
#
# label	: PRICES
# target	: restaurant,restaurant
# term	: worth|though|restaurant
# pred	: PRICES|AMBIENCE|FOOD
# _____________________________________________________________________________________________________
#
# the four seasons has history and it is a sort of landmark of new york city restaurants, but trust me, they will charge you through the nose just so that you can say "i've been to the four seasons restaurant". ~
#
# label	: PRICES
# target	: The Four Seasons,The Four Seasons
# term	: restaurant|restaurant
# pred	: FOOD|FOOD
# _____________________________________________________________________________________________________
#
# i have never left a restaurant feeling as if i was abused, and wasted my hard earned money. ~
#
# label	: PRICES
# target	: restaurant,restaurant
# term	: never|feel|restaurant
# pred	: FOOD|FOOD|AMBIENCE
# _____________________________________________________________________________________________________
#
# i have it a 4 instead of 5 because of the price (just chicken tikka masala - no bread of rice - is $25), which i would expect at a upscale indian restaurant but this place doesn't have an upscale feel. ~
#
# label	: PRICES,PRICES,AMBIENCE
# target	: place,place,chicken tikka masala,feel
# term	: place|would|feel|restaurant|price|$25!-
# pred	: AMBIENCE|FOOD|AMBIENCE|FOOD|PRICES|PRICES
# _____________________________________________________________________________________________________
#
# gorgeous place ideal for a romantic dinner ~
#
# label	: AMBIENCE
# target	: place,place
# term	: place|dinner|romantic
# pred	: AMBIENCE|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# too bad i had paid an extra $2 for the stone bowl. ~
#
# label	: PRICES
# target	: stone bowl
# term	: stone|bowl|$2!-
# pred	: AMBIENCE|FOOD|PRICES
# _____________________________________________________________________________________________________
#
# possibly the most romantic restaurant in the city ~
#
# label	: AMBIENCE
# target	: Restaurant
# term	: restaurant|romantic
# pred	: FOOD|FOOD
# _____________________________________________________________________________________________________
#
# this is undoubtedly my favorite modern japanese brasserie (that don’t serve sushi), and in my opinion, one of the most romantic restaurants in the city! ~
#
# label	: AMBIENCE
# target	: modern Japanese brasserie,modern Japanese brasserie
# term	: sushi|restaurant|romantic
# pred	: FOOD|FOOD|FOOD
# _____________________________________________________________________________________________________
#
# maybe it was the great company (i had friends visiting from philly – yes, it was not a date this time) or the super reasonable price point, but i just can’t say enough good things about this brasserie. ~
#
# label	: PRICES
# target	: brasserie,brasserie
# term	: good|reasonable|great|price
# pred	: FOOD|PRICES|AMBIENCE|PRICES
# _____________________________________________________________________________________________________
#
# they are extremely rude, not even apologizing for the horrible service we got and handing us a bill well over $500 for some drinks adn their pita bread! ~
#
# label	: SERVICE,PRICES,PRICES,SERVICE
# target	: service,drinks,pita bread,NULL
# term	: service|rude|well|$500!-
# pred	: SERVICE|FOOD|PRICES|PRICES
# _____________________________________________________________________________________________________
#
# only complaint is the pricing--i believe it would be more reasonable to pay a dollar less on each item listed on the menu. ~
#
# label	: PRICES
# target	: menu
# term	: would|menu|reasonable
# pred	: PRICES|FOOD|PRICES
# _____________________________________________________________________________________________________
#
# can’t believe how an expensive nyc restaurant can be so disrespectful to its clients. ~
#
# label	: PRICES,SERVICE
# target	: restaurant,NULL
# term	: restaurant
# pred	: FOOD
# _____________________________________________________________________________________________________
#
# 199 157 88 18 0.6933797909407665 0.9170506912442397 0.7896825396825397
# (199, 157, 88, 18, 0.6933797909407665, 0.9170506912442397, 0.7896825396825397)

# %%
import pandas as pd

# analize("FOOD", '16_baru_nan', True)
