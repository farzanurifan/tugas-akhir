# %%
import re
from nltk import Tree
from pycorenlp import StanfordCoreNLP
import json
import nltk
from nltk.sem.logic import *
import requests
from nltk.corpus import sentiwordnet as swn
nltk.download('sentiwordnet')
import os

read_expr = nltk.sem.Expression.fromstring
nlp = StanfordCoreNLP('http://localhost:9000')
dependency_parser = nlp.annotate
# Out:
# [nltk_data] Downloading package sentiwordnet to C:\Users\Farza
# [nltk_data]     Nurifan\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!

# %% [markdown]
# Babelfy WSD method

# %%
def babelfy(sentence):
    response = []
    token_word = nltk.word_tokenize(sentence)
    url = 'https://babelfy.io/v1/disambiguate?text='+sentence+'&annRes=WN&lang=en&key=57d8ee6f-01f0-46f4-ac1c-0468fb0aae3a'
    r = requests.get(url)
    
    res = r.json()
    
    for x in res:
        tokenFragment = x['tokenFragment']
        startTknFragment = tokenFragment['start']
        endTknFragment = tokenFragment['end']
        babelSynsetID = x['babelSynsetID'];
        response.append((token_word[startTknFragment], babel_info(babelSynsetID)))
    
    return response

def babel_info(synset_id):
    url = 'https://babelnet.io/v5/getSynset?id='+synset_id+'&key=57d8ee6f-01f0-46f4-ac1c-0468fb0aae3a'
    r = requests.get(url)
    res = r.json()

    return '.'.join(res['mainSense'].split('#'))
    

def get_score(sentence):
    resp = babelfy(sentence)
    ss = []
    for (w, sy) in resp:
        swn_senti = swn.senti_synset(sy)
        ss.append((w, sy, swn_senti.pos_score(), swn_senti.neg_score() ))
        
    return ss

# %% [markdown]
# lexicon method

# %%
positive_lexicon = []
negative_lexicon = []

def read_lexicon():
    global positive_lexicon;
    global negative_lexicon;
    
    with open(os.path.join(os.path.abspath('opinion-lexicon-English/') , 'positive-words.txt'), 'r') as file:
        line = file.readline();
        while ";" in line:
            line = file.readline();
         
        positive_lexicon = file.readlines()
    
    with open(os.path.join(os.path.abspath('opinion-lexicon-English/') , 'negative-words.txt'), 'r', encoding = "ISO-8859-1") as file:
        line = file.readline();
        while ";" in line:
            line = file.readline();
        
        negative_lexicon = file.readlines()
        
    positive_lexicon = list(map(lambda word: word.rstrip("\n\r"), positive_lexicon))
    negative_lexicon = list(map(lambda word: word.rstrip("\n\r"), negative_lexicon))
    
        
read_lexicon()

# %%
intensifier_adverb = ['absolutely', 'completely', 'extremely', 'highly', 'rather', 'really', 'very', 'so', 'too', 'totally', 'utterly', 'at all']
negate_adverb = ['no', 'not', 'never', 'none', 'nobody']

# %%
def parser(expression):
    old = expression.replace(' ', '_').replace('>_(', '> (').replace(')_(', ') (').replace(')_)', ') )').replace(')_)', ') )').replace(' (', '(')
    new = ''
    flag = False
    for x in range(0, len(old) - 1):        
        if old[x] == '<':
            flag = True
        if old[x] == '>':
            flag = False
            
        if flag == True:
            if old[x] == '(':
                new += '{'
            elif old[x] == ')':
                new += '}'
            else:
                new += old[x]
        else:
            new += old[x]
    new += old[len(old)-1]
    return new


def pos_tag(sentence):
    result = dependency_parser(sentence, properties={"outputFormat": "json", "annotators": "pos"})['sentences']

    res = []
    for iterate in result:
        for pos in iterate['tokens']:
            res.append(pos['pos'])
    return res


def insert_pos_tag(exp, pos, nltk_pos):
    count = 0
    res = ''
    for x in range(0, len(exp)):
        if exp[x] == 'S' and exp[x+1]==' ' and exp[x+2] == 'P':
            res += 'S '
            #print('count :' + str(count))
            #print("pos")
            #print(len(pos))
            #print('nltk pos')
            #print(len(nltk_pos))
            res += pos[count] + ' ' + nltk_pos[count][1]
            count += 1
        else:
            res += exp[x]  
    return res


def direction(exp):
    cont = False
    for x in exp:
        if x == '{':
            cont = True
        elif x == '}':
            cont = False
            continue
        if cont == True:
            continue
        if x == '/':
            return '/'
        elif x == '\\':
            return '\\'
    return False


def is_type_raising(tree):
    tree_string = str(tree)
    
    # check type raising
    exp = tree_string.split('_')[1]
    pattern_1 = r'(.*?)\\(.*?){(.*?)/(.*?)}'
    pattern_2 = r'(.*?)/(.*?){(.*?)\\(.*?)}'
    
    match = False
    if re.search(pattern_1, exp):
        match = True
    elif re.search(pattern_2, exp):
        match = True
        
    sub = []
    for subtree in tree:
        sub.append(subtree)
    if len(sub) == 1 and match:
        return True
    else:
        return False

    
def map_wnpos_to_pennpos(pos):
    if(pos == 'n'):
        return 'NN'
    elif(pos == 'a'):
        return 'JJ'
    elif(pos == 'v'):
        return 'VB'
    elif(pos == 'r'):
        return 'RB'
    
    
def find_word_in_swn(swn_score, word):
    for (wordd, synset, pos_score, neg_score) in swn_score:
        if(wordd == word):
            return (wordd, synset, pos_score, neg_score)
    
    
def polarity_with_score(pos, neg, word=None, method='swn'):
    if(method == 'swn'):
        if(pos > neg):
            return ('P', round(pos * 10))
        elif(pos < neg):
            return ('Ne', round(neg*10))
        else:
            return ('N', 0)
    elif(method == 'lexicon'):
        if word in positive_lexicon:
            return ('P', 1)
        elif(word in negative_lexicon):
            return ('Ne', 1)
        else:
            return ('N', 0)
    
    
def adverb_type(word):
    if (word in intensifier_adverb):
        return 'I'
    elif(word in negate_adverb):
        return 'Ne'
    else:
        return 'N'
    
    
def pos_majority_voting(corenlp, nltk, babelfy):
    pos = {}
    
    if(corenlp in pos):
        pos[corenlp] += 1
    else:
        pos[corenlp] = 0  
    
    if(nltk in pos):
        pos[nltk] += 1
    else:
        pos[nltk] = 0
        
    if(babelfy in pos):
        pos[babelfy] += 1
    else:
        pos[babelfy] = 0
        
    #find biggeest counter in pos 
    return sorted(pos.items(), key=lambda x: x[1], reverse=True)[0][0];


def chunk(tree):
    # ini cuma masukin ke array 
    chunk = []
    chunk3 = []
    
    for subtree in tree:
        if type(subtree) == nltk.tree.Tree:
            
            # chunk temp array
            subtree_str_array = str(subtree).split('_')
            if subtree_str_array[0][2] == 'L':
                if subtree_str_array[3] == 'NN':
                    chunk.append(subtree_str_array[6])
                    if len(chunk3) == 0:
                        chunk3.append(subtree_str_array[6])
                    
            if len(chunk3) == 1:
                for sub in subtree:
                    # chunk temp array
                    subtree_str_array3 = str(sub).split('_')
                    if subtree_str_array3[0][2] == 'L':
                        if subtree_str_array3[3] == 'NN':
                            chunk3.append(subtree_str_array3[6])
    
    # chunk noun phrase
    if len(chunk) == 2:
        chunk_str = '+'.join(chunk)
        return True, read_expr(r'(' + chunk_str + '_NN_N_0)')
    
    if len(chunk3) == 3:
        chunk_str = '+'.join(chunk3)
        return True, read_expr(r'(' + chunk_str + '_NN_N_0)')
    
    return False, None


def one_child(tree, swn_score):    
    sub = []
    for subtree in tree:
        if type(subtree) == nltk.tree.Tree:
            sub.append(subtree)
    if len(sub) == 1:
        return True, lambda_calculus(sub[0], swn_score), sub
    
    return False, None, sub


def type_raising(first, second, swn_score):    
    if is_type_raising(first):
        if direction(str(first).split('_')[1]) == '/':
            x = read_expr(r'\F x.F(x, ' + str(lambda_calculus(first, swn_score)) + ')')
            y = lambda_calculus(second, swn_score)
            return True, ApplicationExpression(x, y).simplify()
    
    if is_type_raising(second):
        if direction(str(second).split('_')[1]) == '/':
            x = lambda_calculus(first, swn_score)
            y = read_expr(r'\F x.F(x, ' + str(lambda_calculus(second, swn_score)) + ')')
            return True, ApplicationExpression(x, y).simplify()
        
    return False, None
    

def rule_var(ccg, corenlp_pos, nltk_pos, word, swn_score):
    r_word = ['PRP', 'FW', 'NN', 'LS', 'NNS']
    word_swn_score = find_word_in_swn(swn_score, word) if swn_score else None
    pos_score = 0
    neg_score = 0
    babelfy_pos = None;

    if(word_swn_score):
        word, synset, pos_score, neg_score = word_swn_score
        splitted_syns = synset.split('.');
        babelfy_pos = map_wnpos_to_pennpos(splitted_syns[1]);
        
    polarity, score = polarity_with_score(pos_score, neg_score, word, method="lexicon")
    pos = pos_majority_voting(corenlp_pos, nltk_pos, babelfy_pos)
    
    return rule_leaf(ccg, r_word, pos, word, polarity, score)


def rule_leaf(ccg, r_word, pos, word, polarity, score):
    if pos == 'CC':
        return read_expr(r'CC')
    elif pos in r_word:
        return read_expr(word + '_' + pos + '_' + polarity + '_' + str(score))
    elif 'JJ' in pos:
        return read_expr(word + '_' + 'JJ' + '_' + polarity + '_' + str(score))
    elif 'VB' in pos:
        if '{S[dcl]\\NP}/{S[adj]\\NP}' in ccg:
            return read_expr(r'\x.x')
        else:
            return read_expr(r'\X.' + word + '_' + 'VB' + '_' + polarity + '_' + str(score) +'(X)')
    elif 'RB' in pos:
        #Adverb has three types. I: Intensifier, Ne: Negation, N: no affection toward sentiment
        return read_expr(word + '_' + 'RB' + '_' + adverb_type(word))
    elif word == 'of':
        return read_expr('of')
    else:
        return read_expr(r'\x.x')

    
def lambda_calculus(tree, swn_score=None):
    tree_string = str(tree)
    
    # leaf
    if tree_string[2] == 'L':
        splitted = tree_string.split('_')
        ccg = splitted[1]
        corenlp_pos = splitted[3]
        nltk_pos = splitted[4]
        word = splitted[6]
        
        return rule_var(ccg, corenlp_pos, nltk_pos, word, swn_score)
    
    # chunk noun phrase
    is_true, res = chunk(tree)
    if is_true:
        return res
            
    # anak 1
    is_true, res, sub = one_child(tree, swn_score)
    if is_true:
        return res
                        
    # urutan operasi lambda calculusnya    
    first = sub[0]
    second = sub[1]
    
    # type raising
    is_true, res = type_raising(first, second, swn_score)
    if is_true:
        return res    
    
    # urutan
    length_1 = len(str(sub[0]).split('_')[1].replace('\\', '/').split('/'))
    length_2 = len(str(sub[1]).split('_')[1].replace('\\', '/').split('/'))
    if length_2 > length_1:
        first = sub[1]
        second = sub[0]
    
    # rekursi
    return deduction(lambda_calculus(first, swn_score), lambda_calculus(second, swn_score))

# %%
def bool_var(str_a, str_b):
    is_adj_in_a = re.search(r'JJ.*', str_a)
    is_adj_in_b = re.search(r'JJ.*', str_b)
    
    is_adverb_in_a = re.search(r'RB.*', str_a)
    is_adverb_in_b = re.search(r'RB.*', str_b)    
    
    is_noun_in_b = re.search(r'\w*?\+?\w*?\+?\w*_NN.*?_\w*', str_b)
    is_verb_in_b = re.search(r'VB.*?_\w*_\d*', str_b)
    
    return is_adj_in_a, is_adj_in_b, is_adverb_in_a, is_adverb_in_b, is_noun_in_b, is_verb_in_b


def rule_and(str_a, str_b, is_noun_in_b, is_adj_in_a):
    a, b = None, None
    if (str_b == 'CC'):
        a = read_expr(str_b)
        b = read_expr(str_a)
        return True, a, b
        
    if (re.search(r'CC\(', str_a)) and (re.search(r',', str_a)) and is_noun_in_b and is_adj_in_a:
        a = read_expr(r'\x.x')
        b = read_expr(replacer(str_a, str_b))
        return True, a, b
    
    if is_noun_in_b and is_adj_in_a:
        a = read_expr(r'\x.x')
        b = read_expr(replacer(str_a, str_b))
        return True, a, b
        
    
    return False, None, None


def rule_seq(str_a, str_b):
    a, b = None, None
    r_word = ['PRP', 'FW', 'NN', 'LS', 'JJ']
    if '(' not in str_a and '(' not in str_b:
        x = False
        for r in r_word:
            if r in str_a and r in str_b:
                x = True

        if x:
            a = read_expr(r'\x.x')
            b = read_expr('seq(' + str_a + ',' + str_b + ')')
            return True, a, b
    
    return False, None, None


def ini_fungsi_mas_ari_tolong_dipecah_lagi(str_a, str_b, is_adj_in_a, is_adj_in_b, is_adverb_in_a, is_adverb_in_b, is_noun_in_b, is_verb_in_b):
    a, b = None, None
    
    if is_adverb_in_a and (is_noun_in_b and (not is_verb_in_b)):
        #print(is_adverb_in_a)
        #print(is_noun_in_b)
        #print(is_verb_in_b)
        a = read_expr(r'\x.x')
        b = read_expr(r'\x.x')
        return True, a, b

#     elif(is_adj_in_a and is_noun_in_b):
# #         adjective_score = str_a.split('_')[3]
# #         sentiment_polarity = str_a.split('_')[2]
#         pattern = '(\w*_JJ_\w_\d)'
#         adjective_score = re.findall(pattern, str_a)[0].split('_')[3]
#         sentiment_polarity = re.findall(pattern, str_a)[0].split('_')[2]
#         print(adjective_score, sentiment_polarity)
#         #get noun
#         noun_str_b = str_b[ is_noun_in_b.start() : is_noun_in_b.end() ]
#         #change sentiment and polarity
#         def mapFunction(data):
#             idx, x = data
#             if(idx == 2):
#                 return sentiment_polarity
#             elif(idx == 3):
#                 return adjective_score
#             else:
#                 return x
            
#         noun_update_str_b = '_'.join( list(map(mapFunction, enumerate(noun_str_b.split('_')))) )
#         #change str_b for noun filtered with x
#         list_str_b = list(str_b)
#         list_str_b[is_noun_in_b.start() : is_noun_in_b.end()] = 'x'
#         str_b = "".join(list_str_b)
#         print(str_b, noun_update_str_b, is_noun_in_b)
#         str_b = str(ApplicationExpression(read_expr(r"\x." + str_b), read_expr(noun_update_str_b)).simplify())
        
#         a = read_expr(r'\x.x')
#         b = read_expr(str_b)
        
#         return True, a, b
    
    #change identity function for adverb.
    elif( is_adverb_in_a and is_adj_in_b or is_adverb_in_a and is_verb_in_b ):
        #adverb modify adjective
        #example very_RB_I excellent_JJ_P_10 = excellent_JJ_P_20
        #I Intensifier must *2
        #N Negate must *-1
        adverb_type = re.findall('RB.*_\w*', str_a)[0].split('_')[1]
            
        if(adverb_type == 'N'):
            a = read_expr(r'\x.x')
            b = read_expr(str_b)
        elif(adverb_type == 'Ne'):
            #for negation adverb just change polairty
            def mapFunction(data):
                idx, x = data
                if(idx == 2):
                    if(x == 'P'):
                        return 'Ne'
                    elif(x == 'Ne'):
                        return 'P'
                    else:
                        return x
                else:
                    return x

            str_b = '_'.join( list(map(mapFunction, enumerate(str_b.split('_')))) )
            a = read_expr(r'\x.x')
            b = read_expr(str_b)
            
        elif(adverb_type == 'I'):
            #for intensifier adverb. scale adjective value 
            
            # ini bener?
            jj_s = re.findall('JJ.*_\w*_\d*', str_b)
            vb_s = re.findall('VB.*_\w*_\d*', str_b)
            score = '0'
            
            if jj_s:
                score = jj_s[0].split('_')[2]
            else:
                score = vb_s[0].split('_')[2]
                
            def mapFunction(data):
                if(data == score):
                    return str(int(score) * 2);
                else:
                    return data;
            list_str_b = list(str_b)
            str_b = ''.join( list(map(mapFunction, list_str_b)))
#             print(str_b)
            a = read_expr(r'\x.x')
            b = read_expr(str_b)

        return True, a, b
        
    elif( is_adverb_in_a and is_adverb_in_b):
        #adverb modify other adverb
        #kondisi yang jarang bertemu
        adverb_type_in_a = re.findall('RB.*_\w*', str_a)[0].split('_')[1]
        adverb_type_in_b = re.findall('RB.*_\w*', str_b)[0].split('_')[1]
        
        if(adverb_type_in_a == 'Ne' and adverb_type_in_b == 'I'):
            #ganti type b menjadi NE
            def mapFunction(data):
                idx, x = data
                if(idx == 2):
                    return 'Ne'
                else:
                    return x

            str_b = '_'.join( list(map(mapFunction, enumerate(str_b.split('_')))) )
            a = read_expr(r'\x.x')
            b = read_expr(str_b)

        elif(adverb_type_in_a == 'I' and adverb_type_in_b == 'Ne'):
            #tidak meruba
            a = read_expr(r'\x.x')
            b = read_expr(str_b)
        else:
            a = read_expr(r'\x.x')
            b = read_expr(str_b)
            
        return True, a, b

    return False, None, None


def deduction(a, b):
    str_a = str(a)
    str_b = str(b)
    print('old a ' + str_a)
    print('old b ' + str_b)
    
    if str_a == 'of':
        a = read_expr(r'\x.x')
        b = read_expr(r'\x.x')
    
    #change identity function for adjective    
    is_adj_in_a, is_adj_in_b, is_adverb_in_a, is_adverb_in_b, is_noun_in_b, is_verb_in_b = bool_var(str_a, str_b)
    
    # fungsi mas ari
    is_true, a_temp, b_temp = ini_fungsi_mas_ari_tolong_dipecah_lagi(str_a, str_b, is_adj_in_a, is_adj_in_b, is_adverb_in_a, is_adverb_in_b, is_noun_in_b, is_verb_in_b)
    if is_true:
        a = a_temp
        b = b_temp
    
    # and
    is_true, a_temp, b_temp = rule_and(str_a, str_b, is_noun_in_b, is_adj_in_a)
    if is_true:
        a = a_temp
        b = b_temp
                
    # sequence
    is_true, a_temp, b_temp = rule_seq(str_a, str_b)
    if is_true:
        a = a_temp
        b = b_temp  
    
    str_a = str(a)
    str_b = str(b)
    print('new a ' + str_a)
    print('new b ' + str_b)
    print('hasil ' + str(ApplicationExpression(a, b).simplify()))
    print()
    return ApplicationExpression(a, b).simplify()

# %%
def replacer(a, b):
    print(a,b)
    pattern = '\w*?\+?\w*?\+?\w*_NN.*?_'
    mereplace = re.findall(pattern, b)
    res = ''
    for mreplace in mereplace:
        print(mreplace)
        pattern = '\w*_JJ.*_'
        hasil = re.findall(pattern, a)
        if hasil:
            res = a.replace(hasil[0], mreplace)
        if len(hasil) > 1:
            for index in range(1, len(hasil)):
                res = res.replace(hasil[index], mreplace)
    return res

# %%
def preprocessing(sentence):
    res = re.sub(' +', ' ', re.sub(r'[^\w\s]','',sentence.replace("'m", "am").replace("n't", "not").replace("'s", '')))
    return res

# %%
def glue_process(sent):
    preprocessed = preprocessing(sent)
    
    url = "http://localhost:5000/ccgParsing"
    data = {"sent": preprocessed}
    r = requests.post(url, data=data)

    res = r.json()
    
    from_res = res['tree']
    
    text = nltk.word_tokenize(preprocessed)
    nltk_pos = nltk.pos_tag(text)
    
    pos_tagged = insert_pos_tag(from_res, pos_tag(data['sent']), nltk_pos)
    hasil = parser(pos_tagged)

    tree = Tree.fromstring(hasil)
    #swn_score = get_score(preprocessed)
    
#     print(tree)
    return lambda_calculus(tree)

# %%
import pandas as pd

def semua(collection, filename, err_filename):
    df = pd.DataFrame(columns=['sentence', 'lambda', 'raw_aspect', 'aspect', 'sentiment'])
    df_err = pd.DataFrame(columns=['sentence'])
    for data in collection:
        try:
            hasil = glue_process(data)
        
            pattern = '(\w*?\+?\w*_NN_[P|Ne]_\d)'
            aspek = re.findall(pattern, str(hasil))
            aspect = []
            sentiment = []
            temp = ''
            for asp in aspek:
                temp = asp.split('_')
                aspect.append(temp[0].replace('+', ' '))
                sentiment.append(1 if temp[2] == 'P' else 0)

            #print('------------------------')
            #print(aspect, sentiment)
            #print('------------------------')
            df = df.append({'sentence': data, 'lambda': hasil,'raw_aspect': aspek, 'aspect': aspect, 'sentiment': sentiment}, ignore_index=True)
        except:
            df_err = df_err.append({'sentence': data}, ignore_index=True)
        
    df.to_csv(filename)
    df_err.to_csv(err_filename)
    return df

# %%
# input file
df = pd.read_csv("dataset.csv")
# preprocess
sentences = df['review']
labels = df["target"]

semua(sentences[0:300], 'haha.csv', 'haha_error.csv')
# Out:
# elderly_JJ_N_0 group_NN_N_0
# past_JJ_N_0 week_NN_N_0
# recent_JJ_N_0 trip_NN_N_0
# easy_JJ_P_1 was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_N_0,trip_NN_N_0),i_FW_N_0,fact_NN_N_0(\X.use_VB_N_0(X)))
# CC(\X.press_VB_N_0(X),green_JJ_N_0(\X.turn_VB_N_0(X))) rest_NN_N_0
# super_JJ_P_1 fine_NN_P_1
# seq(best_JJ_P_1,possible_JJ_N_0) setting_NN_N_0
# visable_JJ_N_0 loss_NN_Ne_1
# external_JJ_N_0 CC(lense_NN_N_0(seq(filters_NNS_N_0,choices_NNS_N_0)),flash_NN_N_0)
# many_JJ_N_0 options_NNS_N_0
# excellent_JJ_P_1 seq(quality_NN_N_0,pictures_NNS_N_0)
# great_JJ_P_1 job+canon_NN_N_0
# digital_JJ_N_0 camera_NN_N_0
# first_JJ_N_0 camera_NN_N_0
# single_JJ_N_0 cent_NN_N_0
# worth_JJ_P_1 it_PRP_N_0(\X.spent_VB_N_0(X),cent_NN_N_0,i_FW_N_0)
# full_JJ_N_0 manual+control_NN_N_0
# slrlike_JJ_N_0 camera_NN_N_0
# little_JJ_N_0 overview+powershot+g3_NN_N_0
# different_JJ_N_0 kind_NN_N_0
# high_JJ_N_0 seq(quality_NN_N_0,images_NNS_N_0)
# great_JJ_P_1 kingston+512mb+cf_NN_N_0
# cf_JJ_N_0 type_NN_N_0(ii_LS_N_0(microdrives_NNS_N_0))
# perfect_JJ_P_1 CC(hey_VB_N_0(nothing_NN_N_0),like_VB_Ne_1(things_NNS_N_0,i_FW_N_0))
# main_JJ_N_0 dial_NN_N_0
# backlit_JJ_N_0 dial_NN_N_0
# optical_JJ_N_0 viewfinder_NN_N_0
# viewfinder_NN_N_0(visible_JJ_N_0) lens_NN_N_0
# different_JJ_N_0 CC(seq(megapixel_NN_N_0,cameras_NNS_N_0),\x.x)
# high_JJ_N_0 resolution_NN_N_0(seq(sample_NN_N_0,images_NNS_N_0))
# functional_JJ_N_0 conveniences_NNS_N_0
# pleased_JJ_P_1 offers_VB_N_0(features_NNS_N_0,flexibility_NN_P_1(CC(seq(conveniences_NNS_N_0,camera_NN_N_0),automation_NN_N_0),quality_NN_N_0,speed_NN_N_0,picture_NN_N_0))
# automatic_JJ_N_0 settings_NNS_N_0
# bad_JJ_Ne_1 picture_NN_N_0
# enormous_JJ_N_0 quality_NN_N_0
# CC(have_VB_N_0(say_VB_N_0(satisfied_JJ_P_2(i_FW_N_0)),i_FW_N_0)) bought_VB_N_0(canon+g3_NN_N_0,i_LS_N_0)
# digital_JJ_N_0 cameras_NNS_N_0
# smaller_JJ_N_0 cameras_NNS_N_0
# many_JJ_N_0 cameras_NNS_N_0
# slower_JJ_Ne_1 seq(shutter_NN_N_0,speeds_NNS_N_0)
# wide_JJ_N_0 angle_NN_N_0
# is_VB_N_0(set_VB_N_0(angle_NN_N_0),lens_NN_N_0,viewfinder_NN_N_0(visible_JJ_N_0)) lens_NN_N_0
# CC(use_VB_N_0(lcd_NN_N_0,most_JJ_N_0,i_FW_N_0,is_VB_N_0(much_JJ_N_0,\x.x))) is_VB_N_0(set_VB_N_0(angle_NN_N_0),lens_NN_N_0,viewfinder_NN_N_0(lens_NN_N_0))
# minor_JJ_N_0 disappointment_NN_Ne_1
# digital_JJ_N_0 photography_NN_N_0
# serious_JJ_N_0 photography_NN_N_0
# full_JJ_N_0 day_NN_N_0
# CC(have_VB_N_0(say_VB_N_0(wonderful_JJ_P_1(it_PRP_N_0)),i_FW_N_0)) day_NN_N_0(had_VB_N_0(camera_NN_N_0),i_LS_N_0)
# photo_JJ_N_0 quality_NN_N_0
# amazing_JJ_P_1 quality_NN_N_0
# digital_JJ_N_0 cameras_NNS_N_0
# own_JJ_N_0 features_NNS_N_0
# little_JJ_N_0 display+panel_NN_N_0
# top_JJ_P_1 display+panel_NN_N_0
# accurate_JJ_P_1 adjustment_NN_N_0
# darn_JJ_N_0 diopter+adjustment_NN_N_0
# dial_NN_N_0(get_VB_N_0(know_VB_N_0(is_VB_N_0(is_VB_N_0(eyesight_NN_N_0(adjust_VB_N_0(focus_NN_N_0)),it_PRP_N_0),diopter+adjustment_NN_N_0),\x.x,adjustment_NN_N_1),t_NN_N_0,you_PRP_N_0,\X.turn_VB_N_0(X),CC(hard_JJ_Ne_1,small_JJ_N_0))) diopter+adjustment_NN_N_0
# accurate_JJ_P_1 review_NN_N_0
# learn_VB_N_0(more_JJ_N_0,i_FW_N_0) post_VB_N_0(review_NN_N_1,i_FW_N_0)
# much_JJ_N_0 fun_NN_P_1
# excellent_JJ_P_1 photos_NNS_N_0
# be_VB_N_0(creative_JJ_P_1) latitude_NN_N_0
# excellent_JJ_P_1 range_NN_N_0
# great_JJ_P_1 switch_VB_N_0(CC(see_VB_N_0(it_PRP_N_0,working_VB_N_0(lcd+screen_NN_N_0)),spot_VB_N_0(metering_NN_N_0)))
# right_JJ_P_1 target+market_NN_N_0
# nice_JJ_P_1 seq(4x_NN_N_0,zoom_NN_N_0)
# flexible_JJ_P_2 focusing_VB_N_0(system_NN_N_0)
# tough_JJ_P_1(\X.focus_VB_N_0(X)) scene_NN_N_0
# heavy_JJ_N_0 battery_NN_N_0
# solid_JJ_Ne_2 uses_VB_N_0(battery_NN_N_0)
# same_JJ_N_0 size_NN_N_0
# bulky_JJ_Ne_1(it_PRP_N_0) size_NN_N_0
# wonderful_JJ_P_1 set_NN_N_0
# easy_JJ_P_1 pictures_NNS_N_0
# digital_JJ_N_0 zoom_NN_N_0
# highest_JJ_N_0 zoom_NN_N_0
# seq(little_JJ_N_0,blurry_JJ_Ne_1) seq(zoom_NN_N_0,pictures_NNS_N_0)
# nice_JJ_P_2 addition_NN_N_0
# digital_JJ_N_0 zoom_NN_N_0
# optical_JJ_N_0 zoom_NN_N_0
# great_JJ_P_1 zoom_NN_N_0
# optical_JJ_N_0 seq(zoom_NN_N_0,pictures_NNS_N_0)
# digital_JJ_N_0 pictures_NNS_N_0
# purple_JJ_N_0 fringing_NN_N_0(etc_FW_N_0)
# digital_JJ_N_0 pictures_NNS_N_0
# CC(easy_JJ_P_1(\X.use_VB_N_0(X)),nice_JJ_P_2) used_VB_N_0(CC(manage_VB_N_0(seq(computer_NN_N_0,pictures_NNS_N_0)),download_VB_N_0(sort+upload_NN_N_0)),canon+computer+software_NN_N_0)
# it_PRP_N_0(CC(\X.come_VB_N_0(X),snug_JJ_N_0)) lens+cap_NN_N_0
# minor_JJ_N_0 issues_NNS_Ne_1
# only_JJ_N_0 issues_NNS_Ne_0
# easy_JJ_P_1(\X.use_VB_N_0(X)) buttons_NNS_N_0
# fantastic_JJ_P_1 camera_NN_N_0
# digital_JJ_N_0 cameras_NNS_N_0
# best_JJ_P_1 bargain_NN_P_1
# available_JJ_P_1 seq(cameras_NNS_N_0,bargain_NN_P_1)
# creative_JJ_P_1 control_NN_N_0
# imaginable_JJ_N_0 control_NN_N_1
# advanced_JJ_P_1 photobugs_NNS_N_0
# perfect_JJ_P_1 pictures_NNS_N_0
# full_JJ_N_0 auto+setting_NN_N_0
# photo_JJ_N_0 quality_NN_N_0
# awesome_JJ_P_1 quality_NN_N_0
# will_NNS_N_0(the_VB_N_0(\x.x,CC(and_JJ_N_0,to_JJ_N_0(\x.x)))) cameras_NN_N_0(\X.used_VB_N_0(X),\x.x)
# moderate_JJ_N_0 price+difference_NN_N_0
# huge_JJ_N_0 step_NN_N_0
# more_JJ_N_0 CC(shoot_NN_N_0,point_NN_N_0)
# faster_JJ_P_1 lense_NN_N_0
# extended_JJ_N_0 zoom+range_NN_N_0
# better_JJ_P_1 camera_NN_N_0
# reasonable_JJ_P_1 price_NN_N_0(is_VB_N_0(\x.x,\x.x))
# great_JJ_P_1 pictures_NNS_N_0
# chrome_JJ_N_0 casing_NN_N_0
# single_JJ_N_0 charge_NN_N_0(CC(casing_NN_N_0(it_PRP_N_0,beautiful_JJ_P_1,it_PRP_N_0),\x.x))
# other_JJ_N_0 camera_NN_N_0
# friendly_JJ_P_1 canon_NN_N_0
# compactflash_JJ_N_0 card_NN_N_0
# larger_JJ_N_0 card_NN_N_0
# least_JJ_N_0(\x.x) recommend_VB_P_1(card_NN_N_0)
# CC(canon_NN_N_0(great_JJ_P_1,it_PRP_N_0)) simpletech_NN_N_0(bought_VB_N_0(mb+card_NN_N_0),i_LS_N_0)
# same_JJ_N_0 time_NN_N_0
# larger_JJ_N_0 cf+card_NN_N_0
# great_JJ_P_1 colorimetry_NN_N_0
# beautiful_JJ_P_1 prints_NNS_N_0
# expected_VB_N_0(i_FW_N_0,less_JJ_N_0) output_NN_N_0
# optical_JJ_N_0 finder_NN_N_0
# other_JJ_N_0 company_NN_N_0
# other_JJ_N_0 brands_NNS_N_0
# more_JJ_N_0 power_NN_N_0
# spare_JJ_N_0 batteries_NNS_N_0
# proprietary_JJ_Ne_1 seq(canon_NN_N_0,batteries_NNS_N_0)
# great_JJ_P_1 camera_NN_N_0
# makes_VB_N_0(it_PRP_N_0,easy_JJ_P_2) novice_NN_N_0(\X.use_VB_N_0(X))
# great_JJ_P_1 photos_NNS_N_0
# fstop_JJ_N_0 shutter+speed_NN_N_0
# amazing_JJ_P_1 shots_NNS_N_0
# great_JJ_P_1 photos_NNS_N_0
# able_JJ_N_0 take_VB_N_0(photos_NNS_N_1)
# are_VB_N_0(located_JJ_N_0) controls_NNS_N_0
# able_JJ_N_0 having_VB_N_0(fumble_VB_Ne_1(trying_VB_N_0(figure_VB_N_0(are_VB_N_0(controls_NNS_N_0)))),CC(shoot_NN_N_0,point_NN_N_0))
# quick_JJ_N_0 spin_NN_N_0
# photo_JJ_N_0 quality_NN_N_0
# ideal_JJ_P_1 quality_NN_N_0
# full_JJ_N_0 program+mode_NN_N_0
# focal_JJ_N_0 length_NN_N_0
# aperture_JJ_N_0 priority_NN_N_0
# high_JJ_N_0 speed_NN_N_0(seq(subjects_NNS_N_0,priority_NN_N_0))
# shutter_JJ_N_0 CC(aperture_NN_N_0,speed_NN_N_0)
# great_JJ_P_1 CC(weight_NN_N_0,feel_NN_N_0)
# cheap_JJ_Ne_1 plastic+toy_NN_N_0
# CC(slow_JJ_Ne_2,small_JJ_N_0) comes_VB_N_0(\X.packaged_VB_N_0(X),sandisk+card_NN_N_0)
# lexar_JJ_N_0 seq(media_NNS_N_0,cf_NN_N_0)
# digital_JJ_N_0 camera_NN_N_0
# first_JJ_N_0 camera_NN_N_0
# CC(pleased_JJ_P_1(it_PRP_N_0,i_FW_N_0)) is_VB_N_0(camera_NN_N_0,\x.x)
# happy_JJ_P_1 know_VB_N_0(CC(knowledge_NN_N_0,skill_NN_P_1,\X.grow_VB_N_0(X),i_FW_N_0,\X.perform_VB_N_0(X),camera_NN_N_0))
# great_JJ_P_1 megapixels_NNS_N_0
# me_PRP_N_0(fine_JJ_P_1) thing_NN_N_0
# simple_JJ_N_0 point_NN_N_0
# outstanding_JJ_P_1 camera_NN_N_0
# complex_NN_Ne_1(simple_JJ_N_0(take_VB_N_0(you_PRP_N_0))) camera_NN_N_1
# amazing_JJ_P_2 product_NN_N_0
# excellent_JJ_P_1 photos_NNS_N_0
# day_NN_N_0(clear_JJ_P_1) night+mode_NN_N_0
# easy_JJ_P_1(get_VB_N_0(used_VB_N_0(it_PRP_N_0),you_PRP_N_0,\X.use_VB_N_0(X))) camera_NN_N_0
# only_JJ_N_0 drawback_NN_Ne_1
# minor_JJ_N_0 problem_NN_Ne_1
# nikon_JJ_N_0(\x.x) iso_NN_N_0
# few_JJ_N_0 days_NNS_N_0
# first_JJ_N_0 feelings_NNS_N_0
# digital_JJ_N_0 imaging_NN_N_0
# great_JJ_P_2 eliminated_VB_N_0(seq(imaging_NN_N_0,doubt_NN_Ne_1),it_PRP_N_0)
# loose_JJ_Ne_1 lens+cover_NN_N_0
# potential_JJ_N_0 damage_NN_Ne_1
# few_JJ_N_0 times_NNS_N_0
# shaky_JJ_Ne_1(hope_VB_N_0(ll_VB_N_0(feel_VB_N_0(uneasy_JJ_Ne_1),you_PRP_N_0,\X.operate_VB_N_0(X),it_PRP_N_0),i_FW_N_0)) zooming_VB_N_0(lever_NN_N_0)
# last_JJ_N_0 week_NN_N_0
# reputable_JJ_P_1 seller_NN_N_0
# great_JJ_P_1 deal_NN_N_0
# CC(great_JJ_P_1(they_PRP_N_0)) took_VB_N_0(hundreds_NNS_N_0)
# white_JJ_N_0 balance_NN_N_0
# great_JJ_P_1 seq(colors_NNS_N_0,pictures_NNS_N_0)
# same_JJ_N_0 price+range_NN_N_0
# optical_JJ_N_0 zoom_NN_N_0
# price+range_NN_N_0(other_JJ_N_0,higher_JJ_N_0) seq(4x_NN_N_0,zoom_NN_N_0)
# little_JJ_N_0 bit_NN_N_0
# few_JJ_N_0 months_NNS_N_0
# expensive_JJ_Ne_2 months_NNS_N_0
# minimal_JJ_N_0 effort_NN_N_0
# superior_JJ_P_1 results_NNS_N_0
# light_JJ_N_0 situations_NNS_N_0
# low_JJ_N_0 situations_NNS_N_0
# much_JJ_N_0 action_NN_N_0
# terrible_JJ_Ne_1 grain_NN_N_0
# outdoor_JJ_N_0 photos_NNS_N_0
# awesome_JJ_P_1 photos_NNS_N_0
# simple_JJ_N_0 point_NN_N_0
# consider_VB_N_0(seq(cheaper_JJ_P_1,digital_JJ_N_0)) CC(shoot_VB_N_0(photography_NN_N_0),point_NN_N_0)
# extra_JJ_N_0 resolution_NN_N_0
# high_JJ_N_0 quality_NN_N_0
# external_JJ_N_0 flash+equipment_NN_N_0
# professional_JJ_N_0 seq(quality_NN_N_0,flash+equipment_NN_N_0)
# first_JJ_N_0 move_NN_N_0
# full_JJ_N_0 frame+sensor_NN_N_0
# digital_JJ_N_0 slr_NN_N_0
# least_JJ_N_0(\x.x) years_NNS_N_0
# CC(am_VB_N_0(getting_VB_N_0(impatient_JJ_Ne_1),i_FW_N_0)) figure_NN_N_0(is_VB_N_0(\x.x,\x.x),i_LS_N_0)
# clean_JJ_P_1 images_NNS_N_0
# high_JJ_N_0 seq(quality_NN_N_0,images_NNS_N_1)
# light_JJ_N_0 quality_NN_N_0
# unsatisfactory_JJ_Ne_1 quality_NN_N_0
# bright_JJ_P_1 light_NN_N_0
# long_JJ_N_0 lag+time_NN_N_0
# modern_JJ_P_1 film+slr_NN_N_0
# least_JJ_N_0 got_VB_N_0(focus_NN_N_0,seq(lock_NN_N_0,shutter+release_NN_N_0),youve_NN_N_0)
# extreme_JJ_N_0 depth_NN_N_0
# point_NN_N_0(obtainable_JJ_P_1) depth_NN_N_0
# reasonable_JJ_P_1 probability_NN_N_0
# restless_JJ_Ne_1 subject_NN_N_0
# CC(probability_NN_N_1(fire_VB_N_0(shutter_NN_N_0)),strikes_VB_N_0(amusing_JJ_P_1(\X.pose_VB_N_0(X)))) CC(child_NN_N_0,seq(pet_NN_N_0,subject_NN_N_1))
# get_VB_N_0(focus_VB_N_0(lock_JJ_N_0),i_FW_N_0) CC(probability_NN_N_1(fire_VB_N_0(shutter_NN_N_0)),strikes_VB_N_0(child_NN_N_0,seq(pet_NN_N_0,subject_NN_N_0(X))),\X.wait_VB_N_0(X),i_FW_N_0)
# external_JJ_N_0 flash_NN_N_0
# relative_JJ_N_0 \x.nikon+slr_NN_N_0(flash_NN_N_0(\X.achieve_VB_N_0(X)),x,i_FW_N_0)
# proper_JJ_P_1 metz_NN_N_0(CC(extension+cord_NN_N_0,module_NN_N_0))
# ultimate_JJ_N_0 quality_NN_N_0
# absolute_JJ_N_0 quality_NN_N_0
# CC(fstop_JJ_N_0(yourself_PRP_N_0)) set_VB_N_0(shutter+speed_NN_N_0)
# dedicated_JJ_P_1 flashes_NNS_N_0
# thirdparty_JJ_N_0 flashes_NNS_N_0
# second_JJ_N_0 g3_NN_N_0
# is_VB_N_0(\x.want_VB_N_0(do_VB_N_0(most_JJ_N_0),x,youd_NN_N_0)) seq(g3_NN_N_0,shutter+sync_NN_N_0)
# CC(most_JJ_N_0) duration_NN_N_0
# attendant_JJ_N_0 shadows_NNS_N_0
# seq(more_JJ_N_0,direct_JJ_N_0) lighting_NN_N_0
# second_JJ_N_0 problem_NN_Ne_1
# tilted_JJ_N_0 enabling_VB_N_0(you_PRP_N_0,you_PRP_N_0(walls_NNS_N_0(bounce_VB_N_0(flash_NN_N_0))))
# natural_JJ_N_0 light_NN_N_0
# gentlest_JJ_P_1 light_NN_N_0
# shadowfree_JJ_N_0 images_NNS_N_0
# raw_JJ_N_0 image_NN_N_0
# raw_JJ_N_0 image_NN_N_0
# present_JJ_N_0(you_PRP_N_0) image_NN_N_0
# second_JJ_N_0 file_NN_N_0
# raw_JJ_N_0 g3+hardware_NN_N_0
# stunning_JJ_P_1 quality_NN_N_0
# accurate_JJ_P_1 exposure_NN_N_0
# raw_JJ_N_0 image_NN_N_0
# realistic_JJ_P_1 seen_VB_N_0(film_NN_N_0(\X.produced_VB_N_0(X)),ive_JJ_N_0)
# raw_JJ_N_0 plugin_NN_N_0
# designed_VB_N_0(please_VB_N_0(uncritical_JJ_N_0)) fantasy+world_NN_N_0
# raw_JJ_N_0 image+software_NN_N_0
# better_JJ_P_1 anything_NN_N_0
# seq(resolution_NN_N_0,limits_NNS_Ne_1,seen_VB_N_0(anything_NN_N_1),ive_JJ_N_0) put_VB_N_0(seq(cameras_NNS_N_0,limitations_NNS_Ne_1))
# professional_JJ_N_0 flash+system_NN_N_0
# raw_JJ_N_0 images_NNS_N_0
# easy_JJ_P_1 point_NN_N_0
# perfect_JJ_P_1 camera_NN_N_0
# CC(shoot_VB_N_0(had_VB_N_0(most_JJ_N_0(pry_VB_Ne_1(it_PRP_N_0)),i_FW_N_0))) loved_VB_P_1(using_VB_N_0(camera_NN_N_0))
# digital_JJ_N_0 cameras_NNS_N_0
# astounding_JJ_P_1 CC(quality_NN_N_0,breeze_NN_P_1)
# best_JJ_P_1 buy_NN_N_0
# digital_JJ_N_0 cameras_NNS_N_0
# similar_JJ_N_0 priced_VB_N_0(cameras_NNS_N_0)
# other_JJ_N_0 cameras_NNS_N_0
# good_JJ_P_1 month_NN_N_0
# digital_JJ_N_0 camera_NN_N_0(seq(review_NN_N_0,sites_NNS_N_0))
# leading_JJ_P_1 consumer+magazine_NN_N_0
# positive_JJ_P_2 review_NN_N_0
# online_JJ_N_0 reviews_NNS_N_0
# different_JJ_N_0 camera_NN_N_0
# exceptional_JJ_P_1 seq(supplier_NN_N_0,service_NN_N_0)
# perfect_JJ_P_1 condition_NN_N_0
# more_JJ_N_0(\x.x) month_NN_N_0
# topnotch_JJ_P_1 photos_NNS_N_0
# CC(getting_VB_N_0(settings_NNS_N_0,ready_JJ_P_1(\X.shoot_VB_N_0(X)))) cocking_VB_N_0(shutter_NN_N_0)
# manual_JJ_N_0 modes_NNS_N_0
# tremendous_JJ_N_0 flexibility_NN_P_1
# coastal_JJ_N_0 seq(redwood_NN_N_0,forests_NNS_N_0)
# online_JJ_N_0 reviews_NNS_N_0
# legitimate_JJ_N_0 criticsm_NN_N_0
# only_JJ_N_0 criticsm_NN_N_0
# little_JJ_N_0 camera_NN_N_0
# great_JJ_P_1 camera_NN_N_0
# positive_JJ_P_1 things_NNS_N_0
# great_JJ_P_1 fan_NN_N_0
# negative_JJ_Ne_1 expectation_NN_N_0
# difficult_JJ_Ne_1 expectation_NN_N_1
# great_JJ_P_1 gains_NNS_P_1
# most_JJ_N_0 nikons_NNS_N_0
# remote_JJ_N_0 CC(fileviewer+software_NN_N_0,capture_NN_N_0)
# CC(seq(more_JJ_N_0,intuitive_JJ_P_1)) g2_NN_N_0
# easy_JJ_P_1(as_RB_N) CC(CC(seq(g2_NN_N_1),\X.operate_VB_N_0(X)),\X.install_VB_N_0(X))
# better_JJ_P_1 balance_NN_N_0
# CC(less_JJ_N_0(clicking_VB_N_0(\X.shaking_VB_N_0(X)))) balance_NN_N_1
# light_JJ_N_0 autocorrection_NN_N_0
# awesome_JJ_P_1 autocorrection_NN_N_0
# get_VB_N_0(contours_JJ_N_0) right_NN_P_1
# vivid_JJ_P_1 sepia_NN_N_0
# low_JJ_N_0 sharpening_VB_N_0(b_NN_N_0)
# neutral_JJ_N_0 b_NN_N_0
# panoramic_JJ_P_1 view_NN_N_0
# new_JJ_N_0 photostich+software_NN_N_0
# white_JJ_N_0 offsets_NNS_N_0
# seq(much_JJ_N_0,sharper_JJ_P_1) offsets_NNS_N_0
# white_JJ_N_0 edges_NNS_N_0
# straight_JJ_N_0(\x.x) ll_VB_N_0(be_VB_N_0(end_VB_N_0(\x.x,\X.taking_VB_N_0(X),pics_NNS_N_0,you_PRP_N_0,\X.amazed_VB_P_1(X))),you_PRP_N_0)
# dim_JJ_Ne_1 lit_VB_N_0(environs_NNS_N_0)
# other_JJ_N_0 camera_NN_N_0
# little_JJ_N_0 seq(g3_NN_N_0,images_NNS_N_0,\X.criticize_VB_Ne_1(X))
# big_JJ_N_0 mistake_NN_Ne_1
# few_JJ_N_0 seconds_NNS_N_0
# low_JJ_N_0 light_NN_N_0
# blurry_JJ_Ne_1 pictures_NNS_N_0
# many_JJ_N_0 pictures_NNS_N_1
# digital_JJ_N_0 cameras_NNS_N_0
# easy_JJ_P_1(CC(\X.use_VB_N_0(X),\X.understand_VB_N_0(X))) camera_NN_N_0
# great_JJ_P_1 cameras_NNS_N_0
# great_JJ_P_1 pictures_NNS_N_0
# optical_JJ_N_0 zoom_NN_N_0
# great_JJ_P_1 zoom_NN_N_0
# great_JJ_P_1 seq(cp5700_NN_N_0,optics_NNS_N_0)
# small_JJ_N_0 cp5000_NN_N_0
# little_JJ_N_0 cp5000_NN_N_0
# raw_JJ_N_0 format_NN_N_0
# were_VB_N_0(is_VB_N_0(\x.format_NN_N_0(take_VB_N_0(photos_NNS_N_0),x,cp5000_NN_N_0),casual_JJ_N_0(\x.x),lcd+screen_NN_N_0,\x.x,they_PRP_N_0)) drawbacks_NNS_Ne_1
# solid_JJ_P_2 camera_NN_N_0
# great_JJ_P_1 features_NNS_N_0
# CC(easy_JJ_P_1(\X.use_VB_N_0(X))) features_NNS_N_1
# it_PRP_N_0(CC(usefull_JJ_N_0,limited_JJ_Ne_2)) tilting_VB_N_0(lcd+screen_NN_N_0)
# nice_JJ_P_1 camera_NN_N_0
# CC(take_VB_N_0(sharp_JJ_P_1(\x.x))) camera_NN_N_1
# least_JJ_N_0 thumbs_NNS_N_0(received_VB_N_0(fiance+stamp_NN_N_0))
# digital_JJ_N_0 camera_NN_N_0
# CC(own_JJ_N_0(\x.x)) observations_NNS_N_0
# many_JJ_N_0 people_NNS_N_0
# other_JJ_N_0 cameras_NNS_N_0
# great_JJ_P_1 cameras_NNS_N_0
# great_JJ_P_1 camera_NN_N_0
# more_JJ_N_0 features_NNS_N_0
# compactflash_JJ_N_0 card_NN_N_0
# big_JJ_N_0 card_NN_N_0
# \x.32mb_JJ_N_0(\X.comes_VB_N_0(X),x,it_PRP_N_0) card_NN_N_0
# precious_JJ_P_1 shots_NNS_N_0
# digital_JJ_N_0 cameras_NNS_N_0
# digital_JJ_N_0 seq(camera_NN_N_0,friends_NNS_N_0)
# same_JJ_N_0 thing_NN_N_0
#                                               sentence  \
# 0    i recently purchased the canon powershot g3 an...
# 1    after i took their picture with their camera ,...
# 2    they fired away and the picture turned out qui...
# 3    a few of my work constituants owned the g2 and...
# 4    i 'm easily enlarging pictures to 8 1/2 x 11 w...
# 5                                   great job canon !
# 6                                               yep .
# 7    this is my first digital camera , and what a '...
# 8    just a little overview , powershot g3 is the f...
# 9    whether you are a novice or an expert , its ea...
# 10   + you can have different kind of lens if you w...
# 11   i am using kingston 512mb cf which works great...
# 12                       * main dial is not backlit .
# 13             * lens visible in optical viewfinder .
# 14      following my research , i decided on the g3 .
# 15   in a word , " awesome " is how i would describ...
# 16   with the automatic settings , i really have n'...
# 17   i am absolutely in awe of this camera , canon ...
# 18   do n't walk , run and buy this camera if you h...
# 19   i have taken hundreds of photos with it and i ...
# 20                                            flaws ?
# 21   despite this minor disappointment , i highly r...
# 22   the photo quality is amazing and i know i 'm g...
# 23   i 've figured out most of its features on my o...
# 24   i 'm one of those people that can only concent...
# 25   the reason i rated it a four is because of tha...
# 26   i am going to have so much fun with this camer...
# 27                                          positives
# 28   1 ) slr like programming and exposure control ...
# 29      excellent range of metering options as well .
# ..                                                 ...
# 151  ( looks quite neat too suggesting that canon m...
# 152  8 . perhaps inspired by the canon 's factory w...
# 153  9 . in dim lit environs the g2 could easily ou...
# 154  short of the eos range from canon or the d100s...
# 155   this is quite simply the best you can ask for .
# 156         i love my g2 so thought i would upgrade .
# 157                                     big mistake .
# 158  the g3 had problems focusing in low light and ...
# 159                got way too many blurry pictures .
# 160  i have returned the g3 ( actually i tried two ...
# 161  when shopping for digital cameras i looked at ...
# 162                  the nikon 's are great cameras .
# 163  - the drawbacks were that they were not user f...
# 164  olympus c5050 is a very solid camera with a me...
# 165  - i did n't care much for the tilting lcd scre...
# 166             photos had some artifacts and noise .
# 167  my fiance just did n't like the way it felt in...
# 168               we also looked at the fuji fps602 .
# 169  nice camera but does n't take as sharp as pict...
# 170                    fiance did n't like the feel .
# 171                                    the canon g3 .
# 172  a lot of research went into digital camera 's ...
# 173  the other cameras were great and i 'm sure man...
# 174              the powershot g3 is a great camera .
# 175                                             why ?
# 176  4 megapixels is plenty for all but pros , and ...
# 177  it 's slightly lighter than the g2 and packed ...
# 178  the catch with the canon g3 camera , ( and per...
# 179       no one told me , but i wanted to tell you .
# 180     this is not the same thing as a film camera .
#
#                                                 lambda  \
# 0    CC(satisfied_VB_P_1(purchase_NN_N_0),purchased...
# 1    camera_NN_N_0(took_VB_N_0(picture_NN_N_0),i_FW...
# 2    CC(have_VB_N_0(\x.x,\x.x,\X.turned_VB_N_0(X),p...
# 3    CC(recommended_VB_P_1(seq(picture+quality_NN_N...
# 4    am_VB_N_0(CC(using_VB_N_0(seq(setting_NN_N_0))...
# 5                                     job+canon_NN_N_1
# 6                                           yep_NN_N_0
# 7    is_VB_N_0(CC(is_VB_N_0(toy_NN_N_0,it_PRP_N_0),...
# 8    CC(gives_VB_N_0(pictures_NNS_N_0,touch_NN_N_0,...
# 9    are_VB_N_0(CC(expert_NN_N_0,novice_NN_N_0),you...
# 10   etc_FW_N_0(want_VB_N_0(flashes_NNS_N_0),you_PR...
# 11   am_VB_N_0(using_VB_N_0(kingston+512mb+cf_NN_N_...
# 12                                         dial_NN_N_0
# 13                      viewfinder_NN_N_0(lens_NN_N_0)
# 14   g3_NN_N_0(\X.decided_VB_N_0(X),following_VB_N_...
# 15   word_NN_N_0(is_VB_N_0(describe_VB_N_0(camera_N...
# 16   settings_NNS_N_0(taken_VB_N_0(picture_NN_N_1,i...
# 17                            am_VB_N_0(\x.x,i_FW_N_0)
# 18   have_VB_N_0(budget_NN_N_0,you_PRP_N_0,CC(buy_V...
# 19   CC(continue_VB_N_0(be_VB_N_0(quality_NN_N_0(\X...
# 20                                      flaws_NNS_Ne_1
# 21   disappointment_NN_Ne_0(recommend_VB_P_1(seq(ph...
# 22   CC(know_VB_N_0(am_VB_N_0(going_VB_N_0(features...
# 23   ve_FW_N_0(have_VB_N_0(know_VB_N_0(seq(symbols_...
# 24   CC(stop_VB_N_0(me_PRP_N_0,loving_VB_P_1(camera...
# 25   is_VB_N_0(\x.x,rated_VB_N_0(it_PRP_N_0,reason_...
# 26   CC(learn_VB_N_0(review_NN_N_1,i_FW_N_0),am_VB_...
# 27                                   positives_NNS_P_1
# 28   want_VB_N_0(bother_VB_Ne_1(settings_NNS_N_0),y...
# 29                                                \x.x
# ..                                                 ...
# 151  suggesting_VB_N_0(have_VB_N_0(er_NN_N_0,bit_NN...
# 152  has_VB_N_0(seq(offsets_NNS_N_1),CC(had_VB_N_0(...
# 153  CC(maintains_VB_N_0(rep_NN_N_0,\x.x),environs_...
# 154                                         short_RB_N
# 155  is_VB_N_0(ask_VB_N_0(\x.x,best_JJ_P_1,you_PRP_...
# 156  thought_VB_N_0(upgrade_VB_N_0(i_FW_N_0),love_V...
# 157                                    mistake_NN_Ne_0
# 158  CC(CC(had_VB_N_0(been_VB_N_0(seconds_NNS_N_0(\...
# 159            got_VB_N_0(way_NN_N_0,pictures_NNS_N_0)
# 160  CC(have_VB_N_0(g2_NN_N_0),tried_VB_N_0(\x.x),i...
# 161  shopping_VB_N_0(cameras_NNS_N_0,looked_VB_N_0(...
# 162           are_VB_N_0(cameras_NNS_N_1,nikon_NN_N_0)
# 163  were_VB_N_0(is_VB_N_0(\x.format_NN_N_0(take_VB...
# 164  is_VB_N_0(seq(metal+body_NN_N_0,camera_NN_N_2)...
# 165  care_VB_N_0(it_PRP_N_0(CC(lcd+screen_NN_N_2)),...
# 166  had_VB_N_0(CC(noise_NN_Ne_1,artifacts_NNS_N_0)...
# 167  like_VB_Ne_1(hands_NNS_N_0(\X.felt_VB_N_0(X),w...
# 168       looked_VB_N_0(fuji+fps602_NN_N_0,we_PRP_N_0)
# 169               CC(take_VB_N_0(camera_NN_N_1(\x.x)))
# 170            like_VB_Ne_1(feel_NN_N_0,fiance_NN_N_0)
# 171                                    canon+g3_NN_N_0
# 172  had_VB_N_0(needed_VB_N_0(everything_NN_N_0,i_F...
# 173  CC(beg_VB_Ne_1(differ_VB_N_0(CC(observations_N...
# 174       is_VB_N_0(camera_NN_N_1,powershot+g3_NN_N_0)
# 175                                           why_RB_N
# 176  CC(be_VB_N_0(disappointed_VB_Ne_1(results_NNS_...
# 177  CC(packed_VB_N_0(features_NNS_N_0),g2_NN_N_0,l...
# 178  is_VB_N_0(cause_VB_N_0(you_PRP_N_0,miss_VB_Ne_...
# 179  CC(wanted_VB_N_0(tell_VB_N_0(you_PRP_N_0),i_FW...
# 180  is_VB_N_0(seq(film+camera_NN_N_0,thing_NN_N_0)...
#
#                                             raw_aspect  \
# 0               [purchase_NN_N_0, powershot+g3_NN_N_0]
# 1      [camera_NN_N_0, picture_NN_N_0, picture_NN_N_0]
# 2                                     [picture_NN_N_0]
# 3    [picture+quality_NN_N_0, canon_NN_N_0, g2_NN_N_0]
# 4    [setting_NN_N_0, picture+quality_NN_N_0, x_NN_...
# 5                                   [job+canon_NN_N_1]
# 6                                         [yep_NN_N_0]
# 7                          [toy_NN_N_0, camera_NN_N_0]
# 8    [touch_NN_N_0, alsmost_NN_N_0, manual+control_...
# 9                       [expert_NN_N_0, novice_NN_N_0]
# 10                                       [kind_NN_N_0]
# 11                                   b+cf_NN_N_1]
# 12                                       [dial_NN_N_0]
# 13                    [viewfinder_NN_N_0, lens_NN_N_0]
# 14                        [g3_NN_N_0, research_NN_N_0]
# 15                        [word_NN_N_0, camera_NN_N_0]
# 16                                    [picture_NN_N_1]
# 17                                                  []
# 18          [budget_NN_N_0, camera_NN_N_0, run_NN_N_0]
# 19                                    [quality_NN_N_0]
# 20                                                  []
# 21              [photography_NN_N_0, g3+anyone_NN_N_0]
# 22                        [fun_NN_P_1, quality_NN_N_1]
# 23                                                  []
# 24                                     [camera_NN_N_0]
# 25                                     [reason_NN_N_0]
# 26          [review_NN_N_1, camera_NN_N_0, fun_NN_P_0]
# 27                                                  []
# 28   [auto_NN_N_0, progam_NN_N_0, exposure_NN_N_0, ...
# 29                                                  []
# ..                                                 ...
# 151              [er_NN_N_0, bit_NN_N_0, canon_NN_N_0]
# 152  [g3_NN_N_0, user_NN_N_0, canon_NN_N_0, factory...
# 153             [rep_NN_N_0, camera_NN_N_0, g2_NN_N_0]
# 154                                                 []
# 155                                                 []
# 156                                        [g2_NN_N_0]
# 157                                                 []
# 158  [shutter_NN_N_0, shutter_NN_N_0, picture_NN_N_...
# 159                                       [way_NN_N_0]
# 160                             [g2_NN_N_0, g3_NN_N_0]
# 161  [canon+g3_NN_N_0, cp5700+olympus_NN_N_0, nikon...
# 162                                     [nikon_NN_N_0]
# 163                     [format_NN_N_0, cp5000_NN_N_0]
# 164  [metal+body_NN_N_0, camera_NN_N_2, olympus+c50...
# 165                                [lcd+screen_NN_N_2]
# 166                                                 []
# 167                        [way_NN_N_0, fiance_NN_N_0]
# 168                               [fuji+fps602_NN_N_0]
# 169                                    [camera_NN_N_1]
# 170                       [feel_NN_N_0, fiance_NN_N_0]
# 171                                  [canon+g3_NN_N_0]
# 172  [everything_NN_N_0, g3_NN_N_0, purchase_NN_N_0...
# 173                                                 []
# 174               [camera_NN_N_1, powershot+g3_NN_N_0]
# 175                                                 []
# 176                                                 []
# 177                                        [g2_NN_N_0]
# 178            [unresponsiveness_NN_N_0, catch_NN_N_0]
# 179                                       [one_NN_N_0]
# 180                 [film+camera_NN_N_0, thing_NN_N_0]
#
#                                                 aspect              sentiment
# 0                             [purchase, powershot g3]                 [0, 0]
# 1                           [camera, picture, picture]              [0, 0, 0]
# 2                                            [picture]                    [0]
# 3                         [picture quality, canon, g2]              [0, 0, 0]
# 4                        [setting, picture quality, x]              [0, 0, 0]
# 5                                          [job canon]                    [0]
# 6                                                [yep]                    [0]
# 7                                        [toy, camera]                 [0, 0]
# 8    [touch, alsmost, manual control, megapixel, ca...     [0, 0, 0, 0, 0, 0]
# 9                                     [expert, novice]                 [0, 0]
# 10                                              [kind]                    [0]
# 11                                          b cf]                    [0]
# 12                                              [dial]                    [0]
# 13                                  [viewfinder, lens]                 [0, 0]
# 14                                      [g3, research]                 [0, 0]
# 15                                      [word, camera]                 [0, 0]
# 16                                           [picture]                    [0]
# 17                                                  []                     []
# 18                               [budget, camera, run]              [0, 0, 0]
# 19                                           [quality]                    [0]
# 20                                                  []                     []
# 21                            [photography, g3 anyone]                 [0, 0]
# 22                                      [fun, quality]                 [1, 0]
# 23                                                  []                     []
# 24                                            [camera]                    [0]
# 25                                            [reason]                    [0]
# 26                               [review, camera, fun]              [0, 0, 1]
# 27                                                  []                     []
# 28   [auto, progam, exposure, latitude, exposure co...  [0, 0, 0, 0, 0, 0, 0]
# 29                                                  []                     []
# ..                                                 ...                    ...
# 151                                   [er, bit, canon]              [0, 0, 0]
# 152        [g3, user, canon, factory, whitecorrection]        [0, 0, 0, 0, 0]
# 153                                  [rep, camera, g2]              [0, 0, 0]
# 154                                                 []                     []
# 155                                                 []                     []
# 156                                               [g2]                    [0]
# 157                                                 []                     []
# 158             [shutter, shutter, picture, light, g3]        [0, 0, 0, 0, 0]
# 159                                              [way]                    [0]
# 160                                           [g2, g3]                 [0, 0]
# 161           [canon g3, cp5700 olympus, nikon cp5000]              [0, 0, 0]
# 162                                            [nikon]                    [0]
# 163                                   [format, cp5000]                 [0, 0]
# 164                [metal body, camera, olympus c5050]              [0, 0, 0]
# 165                                       [lcd screen]                    [0]
# 166                                                 []                     []
# 167                                      [way, fiance]                 [0, 0]
# 168                                      [fuji fps602]                    [0]
# 169                                           [camera]                    [0]
# 170                                     [feel, fiance]                 [0, 0]
# 171                                         [canon g3]                    [0]
# 172            [everything, g3, purchase, camera, lot]        [0, 0, 0, 0, 0]
# 173                                                 []                     []
# 174                             [camera, powershot g3]                 [0, 0]
# 175                                                 []                     []
# 176                                                 []                     []
# 177                                               [g2]                    [0]
# 178                          [unresponsiveness, catch]                 [0, 0]
# 179                                              [one]                    [0]
# 180                               [film camera, thing]                 [0, 0]
#
# [181 rows x 5 columns]

# %%
preprocessing("i did n't think i would find this quality and ease of use for under $ 1500 - i 'm thrilled with my purchase !")
# Out:
# 'i did not think i would find this quality and ease of use for under 1500 i am thrilled with my purchase '

# %%
glue_process("the camera is very easy to use , in fact on a recent trip this past week i was asked to take a picture of a vacationing elderly group . ")
# Out:
# old a elderly_JJ_N_0
# old b group_NN_N_0
# elderly_JJ_N_0 group_NN_N_0
# group_NN_
# new a \x.x
# new b group_NN_0
# hasil group_NN_0
#
# old a \X.vacationing_VB_N_0(X)
# old b group_NN_0
# new a \X.vacationing_VB_N_0(X)
# new b group_NN_0
# hasil vacationing_VB_N_0(group_NN_0)
#
# old a \x.x
# old b vacationing_VB_N_0(group_NN_0)
# new a \x.x
# new b vacationing_VB_N_0(group_NN_0)
# hasil vacationing_VB_N_0(group_NN_0)
#
# old a of
# old b vacationing_VB_N_0(group_NN_0)
# new a \x.x
# new b \x.x
# hasil \x.x
#
# old a \x.x
# old b picture_NN_N_0
# new a \x.x
# new b picture_NN_N_0
# hasil picture_NN_N_0
#
# old a \x.x
# old b picture_NN_N_0
# new a \x.x
# new b picture_NN_N_0
# hasil picture_NN_N_0
#
# old a \X.take_VB_N_0(X)
# old b picture_NN_N_0
# new a \X.take_VB_N_0(X)
# new b picture_NN_N_0
# hasil take_VB_N_0(picture_NN_N_0)
#
# old a \x.x
# old b take_VB_N_0(picture_NN_N_0)
# new a \x.x
# new b take_VB_N_0(picture_NN_N_0)
# hasil take_VB_N_0(picture_NN_N_0)
#
# old a \X.asked_VB_N_0(X)
# old b take_VB_N_0(picture_NN_N_0)
# new a \X.asked_VB_N_0(X)
# new b take_VB_N_0(picture_NN_N_0)
# hasil asked_VB_N_0(take_VB_N_0(picture_NN_N_0))
#
# old a \X.was_VB_N_0(X)
# old b asked_VB_N_0(take_VB_N_0(picture_NN_N_0))
# new a \X.was_VB_N_0(X)
# new b asked_VB_N_0(take_VB_N_0(picture_NN_N_0))
# hasil was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)))
#
# old a past_JJ_N_0
# old b week_NN_N_0
# past_JJ_N_0 week_NN_N_0
# week_NN_
# new a \x.x
# new b week_NN_0
# hasil week_NN_0
#
# old a \x.x
# old b week_NN_0
# new a \x.x
# new b week_NN_0
# hasil week_NN_0
#
# old a recent_JJ_N_0
# old b trip_NN_N_0
# recent_JJ_N_0 trip_NN_N_0
# trip_NN_
# new a \x.x
# new b trip_NN_0
# hasil trip_NN_0
#
# old a \x.x
# old b trip_NN_0
# new a \x.x
# new b trip_NN_0
# hasil trip_NN_0
#
# old a week_NN_0
# old b trip_NN_0
# new a \x.x
# new b seq(week_NN_0,trip_NN_0)
# hasil seq(week_NN_0,trip_NN_0)
#
# old a \x.was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),x,i_FW_N_0)
# old b seq(week_NN_0,trip_NN_0)
# new a \x.was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),x,i_FW_N_0)
# new b seq(week_NN_0,trip_NN_0)
# hasil was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0)
#
# old a \x.x
# old b was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0)
# new a \x.x
# new b was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0)
# hasil was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0)
#
# old a \x.x
# old b fact_NN_N_0
# new a \x.x
# new b fact_NN_N_0
# hasil fact_NN_N_0
#
# old a fact_NN_N_0
# old b \X.use_VB_N_0(X)
# new a fact_NN_N_0
# new b \X.use_VB_N_0(X)
# hasil fact_NN_N_0(\X.use_VB_N_0(X))
#
# old a was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0)
# old b fact_NN_N_0(\X.use_VB_N_0(X))
# new a was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0)
# new b fact_NN_N_0(\X.use_VB_N_0(X))
# hasil was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0,fact_NN_N_0(\X.use_VB_N_0(X)))
#
# old a \x.x
# old b was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0,fact_NN_N_0(\X.use_VB_N_0(X)))
# new a \x.x
# new b was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0,fact_NN_N_0(\X.use_VB_N_0(X)))
# hasil was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0,fact_NN_N_0(\X.use_VB_N_0(X)))
#
# old a easy_JJ_P_1
# old b was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0,fact_NN_N_0(\X.use_VB_N_0(X)))
# easy_JJ_P_1 was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_0,trip_NN_0),i_FW_N_0,fact_NN_N_0(\X.use_VB_N_0(X)))
# picture_NN_
# week_NN_
# trip_NN_
# fact_NN_
# new a \x.x
# new b fact_NN_1
# hasil fact_NN_1
#
# old a very_RB_I
# old b fact_NN_1
# new a \x.x
# new b \x.x
# hasil \x.x
#
# old a \x.x
# old b \x.x
# new a \x.x
# new b \x.x
# hasil \x.x
#
# old a \x.x
# old b camera_NN_N_0
# new a \x.x
# new b camera_NN_N_0
# hasil camera_NN_N_0
#
# old a \x.x
# old b camera_NN_N_0
# new a \x.x
# new b camera_NN_N_0
# hasil camera_NN_N_0
# <ConstantExpression camera_NN_N_0>

# %%
pattern = '\w*?\+?\w*?\+?\w*_NN.*?_'
re.findall(pattern, 'was_VB_N_0(asked_VB_N_0(take_VB_N_0(picture_NN_N_0)),seq(week_NN_N_0,trip_NN_N_0),i_FW_N_0,fact_NN_N_0(\X.use_VB_N_0(X)))')
# Out:
# ['picture_NN_', 'week_NN_', 'trip_NN_', 'fact_NN_']
