# %%
import pandas as pd

df = pd.read_csv('dataset/res16.csv')

count = 0
sf = pd.DataFrame(columns=['reviewID', 'sentenceID', 'review', 'target', 'category', 'polarity'])

for index, cat in enumerate(df['category']):
    category = cat.split(',')
    ncat = []
    sent_temp = []
    target = df['target'][index]
    if type(target) == float:
        print(category, target)
        continue
    if target == "NULL,NULL,NULL" or target == "NULL,NULL" or target == "NULL":
        continue
    for c in category:
        x = c.split('#')
        if x[1] == "PRICES":
            ncat.append("PRICES")
        elif x[0] == "AMBIENCE" or x[0] == "LOCATION":
            ncat.append("AMBIENCE")
        elif x[0] == "DRINKS" or x[0] == "FOOD":
            ncat.append("FOOD")
        elif x[0] == "SERVICE":
            ncat.append("SERVICE")
        else:
            continue
    if len(ncat) != 0:
        count += 1
        sf = sf.append({'reviewID': df['reviewID'][index],
                        'sentenceID': df['sentenceID'][index],
                        'review': df['review'][index],
                        'target': df['target'][index],
                        'category': ','.join(ncat),
                        'polarity': df['polarity'][index]}, ignore_index=True)
sf.to_csv("dataset/res16_nan_all.csv")
sf.to_excel("dataset/res16_nan_all.xlsx")
print(count)
# Out:
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#STYLE_OPTIONS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['SERVICE#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['FOOD#PRICES'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#PRICES'] nan
# ['LOCATION#GENERAL'] nan
# ['FOOD#STYLE_OPTIONS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#PRICES'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['DRINKS#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#STYLE_OPTIONS'] nan
# ['FOOD#STYLE_OPTIONS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#PRICES'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#PRICES'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#STYLE_OPTIONS'] nan
# ['FOOD#PRICES'] nan
# ['LOCATION#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#PRICES'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#PRICES'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['LOCATION#GENERAL'] nan
# ['RESTAURANT#PRICES'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#STYLE_OPTIONS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#PRICES'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['FOOD#QUALITY'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['DRINKS#QUALITY'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#PRICES'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#PRICES'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['FOOD#PRICES'] nan
# ['FOOD#PRICES'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['FOOD#STYLE_OPTIONS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['LOCATION#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#PRICES'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['DRINKS#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['AMBIENCE#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#STYLE_OPTIONS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['AMBIENCE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['FOOD#PRICES'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['FOOD#QUALITY'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['FOOD#QUALITY'] nan
# ['FOOD#QUALITY'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['FOOD#STYLE_OPTIONS'] nan
# ['FOOD#QUALITY'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#PRICES'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#PRICES'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['RESTAURANT#MISCELLANEOUS'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# ['SERVICE#GENERAL'] nan
# 1057

# %%
import pandas as pd

df = pd.read_csv('dataset/res16_baru.csv')
categories = {}
count = 0
for index, cat in enumerate(df['category']):
    category = cat.split(',')
    ncat = []
    sent_temp = []
    target = df['target'][index]
    for c in category:
        x = c#.split('#')[0]
        if x not in sent_temp:
            try:
                categories[x] += 1
            except:
                categories[x] = 1
        sent_temp.append(x)
print(count)
# Out:
# 0

# %%
for a in categories:
    print( categories[a])
# Out:
# 154
# 217
# 130
# 151
