# %%
import os
import pandas as pd
from nltk.parse.corenlp import CoreNLPDependencyParser

parser = CoreNLPDependencyParser()

positive_lexicon = []
negative_lexicon = []

def read_lexicon():
    global positive_lexicon;
    global negative_lexicon;    
    with open(os.path.join(os.path.abspath('../opinion-lexicon-English/') , 'positive-words.txt'), 'r') as file:
        line = file.readline();
        while ";" in line:
            line = file.readline();
        positive_lexicon = file.readlines()
    with open(os.path.join(os.path.abspath('../opinion-lexicon-English/') , 'negative-words.txt'), 'r', encoding = "ISO-8859-1") as file:
        line = file.readline();
        while ";" in line:
            line = file.readline();
        negative_lexicon = file.readlines()
    positive_lexicon = list(map(lambda word: word.rstrip("\n\r"), positive_lexicon))
    negative_lexicon = list(map(lambda word: word.rstrip("\n\r"), negative_lexicon))
        
read_lexicon()

import os
os.environ["CORENLP_HOME"] = r'C:\stanford-corenlp-full-2018-10-05'


def preprocess(sentences):
    res = []
    for sentence in sentences:
        text = sentence.lower()
        res.append(text)
    return res

import requests
import re

# %%
op_set = positive_lexicon + negative_lexicon
print('more' in op_set)
# Out:
# False

# %%
import os
import pandas as pd
from nltk.parse.corenlp import CoreNLPDependencyParser

parser = CoreNLPDependencyParser()

positive_lexicon = []
negative_lexicon = []

def read_lexicon():
    global positive_lexicon;
    global negative_lexicon;    
    with open(os.path.join(os.path.abspath('../opinion-lexicon-English/') , 'positive-words.txt'), 'r') as file:
        line = file.readline();
        while ";" in line:
            line = file.readline();
        positive_lexicon = file.readlines()
    with open(os.path.join(os.path.abspath('../opinion-lexicon-English/') , 'negative-words.txt'), 'r', encoding = "ISO-8859-1") as file:
        line = file.readline();
        while ";" in line:
            line = file.readline();
        negative_lexicon = file.readlines()
    positive_lexicon = list(map(lambda word: word.rstrip("\n\r"), positive_lexicon))
    negative_lexicon = list(map(lambda word: word.rstrip("\n\r"), negative_lexicon))
        
read_lexicon()

NN = ['NN', 'NNS', 'NNP', 'NNPS']
JJ = ['JJ', 'JJR', 'JJS']



def rule_1_1(parse, f, o_expanded):
    #Rule 1.1
    for (w1, dep, w2) in list(parse.triples()):
        if(dep in dep_DP):
            # Rule 1.1
            if(w1[0] in o_expanded):
                if w2[1] in NN and w2[0] not in f:
                    return True, w2[0], w1[0]
            elif(w2[0] in o_expanded):
                if w1[1] in NN and w1[0] not in f:
                    return True, w1[0], w2[0]
    return False, None, None

def rule_1_2(parse, f, o_expanded):
    # Rule 1.2
    for (w1, dep, w2) in parse.triples():
        if(dep in dep_DP):
            H = ''
            O = ''
            if w1[0] in o_expanded:
                H = w2[0]
                O = w1
            elif w2[0] in o_expanded:
                H = w1[0]
                O = w2

            if H:
                for (w1, dep, w2) in list(parse.triples()):
                    if w1[0] == H and w2[0] != O[0]:
                        if w2[1] in NN and w2[0] not in f:
                            return True, w2[0], O[0]
                    elif w2[0] == H  and w1[0] != O[0]:
                        if w1[1] in NN and w1[0] not in f:
                            return True, w1[0], O[0]
    return False, None, None

def rule_4_1(parse, f, o_expanded):
    # Rule 4.1
    for (w1, dep, w2) in list(parse.triples()):
        if(dep in conj_DP):
            if w1[0] in o_expanded:
                if w2[1] in JJ and w2[0] not in o_expanded:
                    return True, w2[0]

            elif w2[0] in o_expanded:
                if w1[1] in JJ and w1[0] not in o_expanded:
                    return True, w1[0]

    return False, None

def rule_4_2(parse, f, o_expanded):
    # Rule 4.2
    for (w1, dep, w2) in parse.triples():
        if(dep in dep_DP or dep in conj_DP):
            H = ''
            O = ''
            if w1[0] in o_expanded:
                H = w2[0]
                O = w1
            elif w2[0] in o_expanded:
                H = w1[0]
                O = w2

            if H:
                for (w1, dep, w2) in list(parse.triples()):
                    if w1[0] == H and w2[0] != O[0]:
                        if w2[1] in JJ and w2[0] not in o_expanded:
                            return True, w2[0]

                    elif w2[0] == H  and w1[0] != O[0]:
                        if w1[1] in JJ and w1[0] not in o_expanded:
                            return True, w1[0]
    
    return False, None

def rule_3_1(parse, f):
    #Rule 3.1
    for (w1, dep, w2) in list(parse.triples()):
        if(dep in conj_DP):
            if(w1[0] in f): 
                if w2[1] in NN and w2[0] not in f:
                    return True, w2[0], w1[0]
            elif(w2[0] in f):          
                if w1[1] in NN and w1[0] not in f:
                    return True, w1[0], w2[0]
                
    return False, None, None

def rule_3_2(parse, f):
    # Rule 3.2
    for (w1, dep, w2) in parse.triples():
        if(dep in dep_DP or dep in conj_DP):
            H = ''
            O = ''
            if w1[0] in f:
                H = w2[0]
                O = w1
            elif w2[0] in f:
                H = w1[0]
                O = w2

            if H:
                for (w1, dep, w2) in list(parse.triples()):
                    if w1[0] == H and w2[0] != O[0]:
                        if w2[1] in NN and w2[0] not in f:
                            return True, w2[0], O[0]
                    elif w2[0] == H  and w1[0] != O[0]:
                        if w1[1] in NN and w1[0] not in f:
                            return True, w1[0], O[0]

    return False, None, None

def rule_2_1(parse, f, o_expanded):
    # Rule 2.1
    for (w1, dep, w2) in list(parse.triples()):
        if(dep in dep_DP):
            if w1[0] in f:
                if w2[1] in JJ and w2[0] not in o_expanded:
                    return True, w2[0]

            elif w2[0] in f:
                if w1[1] in JJ and w1[0] not in o_expanded:
                    return True, w1[0]
                
    return False, None

def rule_2_2(parse, f, o_expanded):      
    # Rule 2.2
    for (w1, dep, w2) in parse.triples():
        if(dep in dep_DP):
            H = ''
            O = ''
            if w1[0] in f:
                H = w2[0]
                O = w1
            elif w2[0] in f:
                H = w1[0]
                O = w2

            if H:
                for (w1, dep, w2) in list(parse.triples()):
                    if w1[0] == H and w2[0] != O[0]:
                        if w2[1] in JJ and w2[0] not in o_expanded:    
                            return True, w2[0]
                    elif w2[0] == H  and w1[0] != O[0]:
                        if w1[1] in JJ and w1[0] not in o_expanded:
                            return True, w1[0]

    return False, None

# %%
import os
import pandas as pd
import corenlp
import string
import json
from pycorenlp import StanfordCoreNLP
from nltk.parse.corenlp import CoreNLPDependencyParser

os.environ["CORENLP_HOME"] = r'C:\stanford-corenlp-full-2018-10-05'
nlp = StanfordCoreNLP('http://localhost:9000')
client = corenlp.CoreNLPClient()
parser = CoreNLPDependencyParser()
dependency_parser = nlp.annotate

positive_lexicon = []
negative_lexicon = []

NN = ['NN', 'NNS', 'NNP', 'NNPS']
JJ = ['JJ', 'JJR', 'JJS']

conj_DP = ['conj']
dep_DP = ['amod', 'prep', 'nsubj', 'csubj', 'xsubj', 'dobj', 'iobj']

def read_lexicon():
    global positive_lexicon;
    global negative_lexicon;    
    with open(os.path.join(os.path.abspath('../opinion-lexicon-English/') , 'positive-words.txt'), 'r') as file:
        line = file.readline();
        while ";" in line:
            line = file.readline();
        positive_lexicon = file.readlines()
    with open(os.path.join(os.path.abspath('../opinion-lexicon-English/') , 'negative-words.txt'), 'r', encoding = "ISO-8859-1") as file:
        line = file.readline();
        while ";" in line:
            line = file.readline();
        negative_lexicon = file.readlines()
    positive_lexicon = list(map(lambda word: word.rstrip("\n\r"), positive_lexicon))
    negative_lexicon = list(map(lambda word: word.rstrip("\n\r"), negative_lexicon))

def preprocess(sentences):
    res = []
    for sentence in sentences:
        text = sentence.lower()
        res.append(text)
    return res    

def rule_1_1(parse, f, o_expanded):
    #Rule 1.1
    for (w1, dep, w2) in list(parse.triples()):
        if(dep in dep_DP):
            # Rule 1.1
            if(w1[0] in o_expanded):
                if w2[1] in NN and w2[0] not in f:
                    return True, w2[0], w1[0]
            elif(w2[0] in o_expanded):
                if w1[1] in NN and w1[0] not in f:
                    return True, w1[0], w2[0]
    return False, None, None

def rule_1_2(parse, f, o_expanded):
    # Rule 1.2
    for (w1, dep, w2) in parse.triples():
        if(dep in dep_DP):
            H = ''
            O = ''
            if w1[0] in o_expanded:
                H = w2[0]
                O = w1
            elif w2[0] in o_expanded:
                H = w1[0]
                O = w2

            if H:
                for (w1, dep, w2) in list(parse.triples()):
                    if w1[0] == H and w2[0] != O[0]:
                        if w2[1] in NN and w2[0] not in f:
                            return True, w2[0], O[0]
                    elif w2[0] == H  and w1[0] != O[0]:
                        if w1[1] in NN and w1[0] not in f:
                            return True, w1[0], O[0]
    return False, None, None

def rule_4_1(parse, f, o_expanded):
    # Rule 4.1
    for (w1, dep, w2) in list(parse.triples()):
        if(dep in conj_DP):
            if w1[0] in o_expanded:
                if w2[1] in JJ and w2[0] not in o_expanded:
                    return True, w2[0]

            elif w2[0] in o_expanded:
                if w1[1] in JJ and w1[0] not in o_expanded:
                    return True, w1[0]

    return False, None

def rule_4_2(parse, f, o_expanded):
    # Rule 4.2
    for (w1, dep, w2) in parse.triples():
        if(dep in dep_DP or dep in conj_DP):
            H = ''
            O = ''
            if w1[0] in o_expanded:
                H = w2[0]
                O = w1
            elif w2[0] in o_expanded:
                H = w1[0]
                O = w2

            if H:
                for (w1, dep, w2) in list(parse.triples()):
                    if w1[0] == H and w2[0] != O[0]:
                        if w2[1] in JJ and w2[0] not in o_expanded:
                            return True, w2[0]

                    elif w2[0] == H  and w1[0] != O[0]:
                        if w1[1] in JJ and w1[0] not in o_expanded:
                            return True, w1[0]
    
    return False, None

def rule_3_1(parse, f):
    #Rule 3.1
    for (w1, dep, w2) in list(parse.triples()):
        if(dep in conj_DP):
            if(w1[0] in f): 
                if w2[1] in NN and w2[0] not in f:
                    return True, w2[0], w1[0]
            elif(w2[0] in f):          
                if w1[1] in NN and w1[0] not in f:
                    return True, w1[0], w2[0]
                
    return False, None, None

def rule_3_2(parse, f):
    # Rule 3.2
    for (w1, dep, w2) in parse.triples():
        if(dep in dep_DP or dep in conj_DP):
            H = ''
            O = ''
            if w1[0] in f:
                H = w2[0]
                O = w1
            elif w2[0] in f:
                H = w1[0]
                O = w2

            if H:
                for (w1, dep, w2) in list(parse.triples()):
                    if w1[0] == H and w2[0] != O[0]:
                        if w2[1] in NN and w2[0] not in f:
                            return True, w2[0], O[0]
                    elif w2[0] == H  and w1[0] != O[0]:
                        if w1[1] in NN and w1[0] not in f:
                            return True, w1[0], O[0]

    return False, None, None

def rule_2_1(parse, f, o_expanded):
    # Rule 2.1
    for (w1, dep, w2) in list(parse.triples()):
        if(dep in dep_DP):
            if w1[0] in f:
                if w2[1] in JJ and w2[0] not in o_expanded:
                    return True, w2[0]

            elif w2[0] in f:
                if w1[1] in JJ and w1[0] not in o_expanded:
                    return True, w1[0]
                
    return False, None

def rule_2_2(parse, f, o_expanded):      
    # Rule 2.2
    for (w1, dep, w2) in parse.triples():
        if(dep in dep_DP):
            H = ''
            O = ''
            if w1[0] in f:
                H = w2[0]
                O = w1
            elif w2[0] in f:
                H = w1[0]
                O = w2

            if H:
                for (w1, dep, w2) in list(parse.triples()):
                    if w1[0] == H and w2[0] != O[0]:
                        if w2[1] in JJ and w2[0] not in o_expanded:    
                            return True, w2[0]
                    elif w2[0] == H  and w1[0] != O[0]:
                        if w1[1] in JJ and w1[0] not in o_expanded:
                            return True, w1[0]

    return False, None

def get_nouns(sentence, chunk = False):
    text = sentence.lower()
    res = []
    try:
        pattern = '[{pos:NN}] | [{pos:NNS}] | [{pos:NNP}] | [{pos:NNPS}]'
        matches = client.tokensregex(sentence, pattern)
        response = matches['sentences'][0]
        len_chunk = response['length']
        if len_chunk > 0:
            for index in range(0, len_chunk):
                res.append(response[str(index)]['text'])
    except:
        print('err : ', sentence)
        res = []
    return res

def get_adjective(sentence):
    text = sentence.lower()
    res = []
    try:
        pattern = '[{pos:JJ}] | [{pos:JJR}] | [{pos:JJS}]'
        matches = client.tokensregex(sentence, pattern)
        response = matches['sentences'][0]
        len_chunk = response['length']
        if len_chunk > 0:
            for index in range(0, len_chunk):
                res.append(response[str(index)]['text'])
    except:
        print('err : ', sentence)
        res = []
    return res

def get_op_word(noun_pos, opinions):
    temp = 9999
    res = '-'
    for word, index in opinions:
        jarak = abs(index - noun_pos)
        if jarak <= temp:
            res = word
            temp = jarak
    return res

def rem_punct(word):
    return word.translate(str.maketrans('', '', string.punctuation))

def get_ner(sentence):
    result = dependency_parser(sentence, properties={
        "outputFormat": "json",
        "annotators": "ner"})
    res = []
    for obj in result['sentences'][0]['entitymentions']:
        res.append((obj['text'], obj['ner']))
    return res

def modified_double_propagation(O, reviews, output_file, save_to_file, df):
    o_expanded = O
    f = []
    is_stop = False
    flag_cycle = 0
    
    t_a_p = []
    pair_a_o = []
    a_p = []
    r_p = []
    
    while (not is_stop):
        f_i = []
        o_i = []
    
        index = 0

        for sentence in reviews:
            aspect_sentence = []
            if flag_cycle:
                aspect_sentence = t_a_p[index].split('|')
                
            temp = []
            pair = []
                
            try:
                parse = next(parser.raw_parse(sentence))
            except:
                continue

            # Rule 1.1
            is_true, t_a, o = rule_1_1(parse, aspect_sentence, o_expanded)
            if is_true:
                f_i.append(t_a)
                temp.append(t_a)
                pair.append(t_a + '!' + o)

            # Rule 1.2
            is_true, t_a, o = rule_1_2(parse, aspect_sentence, o_expanded)
            if is_true:
                f_i.append(t_a)
                temp.append(t_a)
                pair.append(t_a + '!' + o)

            # Rule 4.1
            is_true, t_o = rule_4_1(parse, f, o_expanded)
            if is_true:
                o_i.append(t_o)

            # Rule 4.2
            is_true, t_o = rule_4_2(parse, f, o_expanded)
            if is_true:
                o_i.append(t_o)


            if flag_cycle == 0:
                r_p.append(sentence)
                a_array = []
                tes = []
                try:
                    tes = df['target'][index].split(', ')
                except:
                    tes = []
                for x in tes:
                    splitted = x.split('[')
                    if len(splitted) > 1:
                        a_array.append(splitted[0] + '!' + splitted[1][0])
                    else:
                        a_array.append(splitted[0])

                a_p.append('|'.join(a_array))
                t_a_p.append('|'.join(temp))
                pair_a_o.append('|'.join(pair))
            else:
                if len(temp) != 0:
                    t_a_p[index] += '|' + '|'.join(temp)
                    pair_a_o[index] += '|' + '|'.join(pair)
            index += 1
            

        #calculate target and opinion expanded
        f = f + f_i 
        o_expanded = o_expanded + o_i

        
        #reread review, and run rule 3.1, 3.2, 2.1, and 2.2
        index = 0
        f_ii = []
        o_ii = []
        
        for sentence in reviews:
            
            aspect_sentence = []
            if flag_cycle:
                aspect_sentence = t_a_p[index].split('|')
                
            temp = []
            pair = []
                
            try:
                parse = next(parser.raw_parse(sentence))
            except:
                continue

            # Rule 3.1
            is_true, t_a, o = rule_3_1(parse, aspect_sentence)
            if is_true:
                f_ii.append(t_a)
                temp.append(t_a)
                pair.append(t_a + '!' + o)

            # Rule 3.2
            is_true, t_a, o = rule_3_2(parse, aspect_sentence)
            if is_true:
                f_ii.append(t_a)
                temp.append(t_a)
                pair.append(t_a + '!' + o)


            # Rule 2.1
            is_true, t_o = rule_2_1(parse, f, o_expanded)
            if is_true:
                o_ii.append(t_o)

            # Rule 2.2
            is_true, t_o = rule_2_2(parse, f, o_expanded)
            if is_true:
                o_ii.append(t_o)

            if len(temp) != 0:
                t_a_p[index] += '|' + '|'.join(temp)
                pair_a_o[index] += '|' + '|'.join(pair)

            index += 1
            
        f_i = f_i + f_ii
        o_i = o_i + o_ii
        f = f + f_ii
        o_expanded = o_expanded + o_ii     
        
        flag_cycle = 1
        
        if(len(f_i) == 0 and len(o_i) == 0):
            for index in range(len(df)):
                new_term = []
                terms = pair_a_o[index].split('|')
                for term in terms:
                    if term == '':
                        continue
                    new_term.append(term)
                    
                if len(new_term) == 0:
                    nn = get_nouns(df['review'][index])
                    for n in nn:
                        new_term.append(n.lower())
                
                    sentence = df['review'][index].replace('-',' ').replace('  ', ' ').strip().lower()
                    tokens = sentence.split(' ')
                    opinion_pos = []
                    opinion_adj = get_adjective(sentence)
                    i = 0
                    for token in tokens:
                        for op in opinion_adj:
                            if op in token:
                                opinion_pos.append((rem_punct(token), i))
                        i += 1
                        
                    i = 0
                    new_pair = []
                    for token in tokens:
                        for nt in new_term:
                            if nt in token and nt != '':
                                op_word = get_op_word(i, opinion_pos)
                                new_pair.append(nt + '!' + op_word)
                    pair_a_o[index] = '|'.join(new_pair)
                
                
                all_ner = []
                ner = get_ner(df['review'][index])
                if len(ner):
                    for word, t in ner:
                        if t != 'MONEY'and t != 'TITLE':
                            all_ner.append(word)
    
                terms_dp = pair_a_o[index].split('|')

                if len(all_ner):
                    new_term = []
                    for t_dp in terms_dp:
                        flag = True
                        for n in all_ner:
                            kata = t_dp.split('!')[0]
                            if kata in n.lower() and kata != '':
                                flag = False
                        if flag:
                            new_term.append(t_dp)
                else:
                    new_term = terms_dp
                
                pair_a_o[index] = '|'.join(new_term)
                
            if save_to_file == True:
                out = pd.DataFrame()
                out['id'] = df['sentenceID']
                out['review'] = df['review']
                out['category'] = df['category']
                out['target'] = df['target']
                out['term'] = pair_a_o
                out['polarity'] = df['polarity']
                out.to_csv(output_file)
            is_stop = True

df = pd.read_csv('dataset/res16_baru.csv')
read_lexicon()
op_set = positive_lexicon + negative_lexicon
modified_double_propagation(op_set, preprocess(df['review']), 'output.csv', True, df)
# Out:
# ['list!interesting', 'wine!interesting', 'values!many']
# ['', 'price!beat']
# ['advanatage!worth', 'half!worth', 'price!worth', 'sushi!worth', 'deal!worth', 'saturday!worth']
# ['menu!worth', 'prix!worth', 'fixe!worth', 'penny!more']
# ['food!fresh']
# ['service!great', 'food!great', 'price!reasonable', 'beginning!great', 'evening!service']
# ['pizza!soggy']
# ['wine!decent', 'prices!decent']
# ['pizza!expensive', 'way!expensive']
# ['toppings!large']
# ['atmosphere!greatest']
# ['selection!great', 'wine!great', 'value!great', 'price!great', 'champagne!price', 'house!value']
# ['', 'dessert!tiny']
# ['', 'drinks!welll']
# ['beers!interesting', 'wines!interesting']
# ['price!reasonable', 'service!poor']
# ['sushi!good']
# ['', 'roll!huge', 'spicy!huge', 'tuna!huge']
# ['choices!limited', 'food!more']
# ['price!great', 'food!great', 'service!great']
# ['price!reasonable']
# ['']
# ['', 'menu!typical', 'restaurant!menu']
# ['', 'wines!average']
# ['food!greatest', 'menu!greatest', 'price!good', 'price!greatest', 'allergies!food', 'prixe!food', 'fixe!food', 'tasting!food']
# ['drinks!-', 'way!-']
# ['resturant!cramped', 'prices!high']
# ['prices!cheap', 'quality!prices']
# ['', 'prices!mortal', 'gods!mortal', 'years!last', 'secret!last']
# ['everytime!exceptional', 'food!exceptional', 'service!food', 'value!food']
# ['place!pricey', 'food!worth']
# ['', 'dishes!average']
# ['prices!cheap']
# ['food!nasty', 'portions!small']
# ['sandwiches!-', 'anything!-', 'chips!-', 'side!-']
# ['prices!authentic']
# ['', 'fallback!only', 'prices!only', 'restaurant!prices']
# ['seafood!good', 'prices!high']
# ['lobster!good', 'sandwich!good', 'price!good']
# ['food!cheap', 'waiters!nice']
# ['plate!delight', 'cheese!delight', 'bargain!plate', 'delight!bargain']
# ['', 'list!extensive', 'wine!extensive']
# ['food!good', 'deal!great', 'place!food', 'self!great']
# ['ambience!fun', 'prices!great', 'fun!prices', 'food!tasty', 'top!fun', 'fact!food']
# ['food!great']
# ['place!wonderful', 'points!wonderful']
# ['price!better', 'pizzas!terrific']
# ['menu!expensive']
# ['food!authentic']
# ['', 'sandwiches!dry']
# ['place!worth', 'prices!place']
# ['food!great']
# ['music!blasted', 'isnt!music']
# ['food!reliable', 'price!moderate']
# ['shanty!recommend', 'vanilla!recommend', 'mmmm!shanty']
# ['location!good', 'college!near', 'hutner!near', 'fact!location', 'prices!reasonable']
# ['rest!worth', 'sum!worth']
# ['decor!cute', 'prices!cute', 'place!little', 'city!affordable']
# ['spreads!great', 'toppings!great']
# ['food!great', 'prices!great', 'service!great', 'service!great']
# ['quality!good', 'place!cheap']
# ['', 'list!extensive', 'wine!extensive']
# ['measures!quibbles', 'liquers!pour-your-own', 'quibbles!off-set', 'bill!off-set']
# ['food!great', 'price!great', 'place!beat']
# ['place!exceeded', 'expectations!exceeded']
# ['food!great', 'wines!good', 'selecion!good', 'prices!selecion']
# ['ravioli!good', 'everything!overpriced', 'bit!everything']
# ['', 'food!average', 'draw!food']
# ['place!bargain']
# ['food!good']
# ['bottles!cheap', 'wine!cheap']
# ['drinks!amazing', 'half!drinks']
# ['food!reasonable', 'prices!reasonable']
# ['food!good', 'tasting!good', 'prices!incredible', 'prices!good']
# ['music!good', 'food!good', 'prices!speedy', 'prices!good', 'service!speedy']
# ['price!-', 'quality!-', 'fish!-', 'return!-', 'visit!-']
# ['decor!fabulous', 'manhattan!trendy', 'restaurant!trendy', 'food!trendy', 'staff!restaurant', 'manhattanite!restaurant', 'side!soho/village/upper', 'west!soho/village/upper', 'prices!side', 'avenue!restaurant', 'clientele!pretentious', 'clientele!soho/village/upper']
# ['restaurants!good', 'uws!good', 'food!overpriced', 'wait-staff!overpriced', 'service!clumsy', 'diner!clumsy', 'management!diner']
# ['side!pricey', 'service!new', 'food!side']
# ['prices!mediocre', 'food!okay']
# ['food!solid', 'decor!solid', 'prices!reasonable', 'prices!nice', 'baluchi!food']
# ['sushi!-']
# ['fish!overpriced', 'chips!overpriced']
# ['meal!good']
# ['food!excellent', 'prices!excellent']
# ['im!fanatical', 'time!fanatical', 'place!im', 'fun!im', 'pirces!im']
# ['food!overpriced', 'service!overpriced']
# err :  Not because you are "The Four Seasons"... – you are allowed to charge an arm and a leg for a romatic dinner.
# err :  not because you are "the four seasons"... – you are allowed to charge an arm and a leg for a romatic dinner.
# ['']
# ['dinner!-', 'manhattan!-', 'feet!-']
# ['guacamole!bland', 'plate!bland']
# ['food!good', 'place!clean']
# ['water!-', 'water!-', 'table!-', 'voss!-', 'bottles!-', 'water!-', 'water!-', 'piece!-']
# ['food!decent', 'price!decent', 'people!friendly', 'people!decent']
# ['', 'prices!high', 'view!prices']
# ['price!-', 'prestige!-', 'location!-']
# ['restaurant!-', 'food!-']
# ['prices!fair', 'board!prices']
# ['place!great', 'value!great']
# ['', 'food!flavorful']
# ['service!helpful', 'price!helpful', 'dish!helpful']
# ['martinis!amazing']
# ['dinner!-', 'wine!-']
# ['environment!-', 'name!-']
# ['place!classy']
# ['restaurant!expensive']
# ['', 'restaurants!new', 'landmark!new', 'city!new']
# ['', 'service!ok']
# ['home!necessary', 'visit!necessary', 'casa!necessary', 'la!necessary', 'femme!necessary', 'visit!necessary', 'diners!necessary', 'money!necessary', 'time!necessary']
# ['drinks!horrible']
# ['dinner!-']
# ['show!missed', 'food!enjoy', 'wallets!empy', 'experience!good', 'dancers!food', 'belly!food']
# ['', 'bill!inedible', 'portion!bill']
# ['money!wasted']
# ['side!expensive', 'food!good']
# ['restaurant!upscale', 'feel!upscale', 'price!feel', 'place!feel']
# ['something!complimentary', 'food!indian']
# ['buffet!expensive', 'lunch!expensive']
# ['stone!bad', 'bowl!bad']
# ['deal!wonderful', 'bbe!wonderful', 'party!bbe']
# ['company!great', 'date!super', 'point!super', 'price!super', 'things!date', 'brasserie!good']
# ['service!horrible']
# ['meat!fresh', 'kimchi!good', 'sauces!great', 'salad!kimchi', 'meal!salad', 'service!meal']
# ['food!good', 'price!high']
# ['bite!fishy', 'salmon!fishy', 'salmon!fishy', 'years!fishy', 'restaurants!fishy', 'salmon!fishy', 'salmon!fishy', 'flatbush!fishy', 'farms!fishy']
# ['eggplant!cold']
# ['pricing!complaint']
# ['service!better']
# ['joint!hot', 'dog!hot', 'glance!first', 'bark!dog']
# ['restaurant!disrespectful', 'nyc!disrespectful', 'clients!restaurant']
# ['bread!stale']
# ['', 'place!empty']
# ['food!lousy', 'portions!tiny']
# ['food!consistently', 'times!many']
# ['confit!amazing', 'duck!amazing']
# ['cart!ive', 'attendant!ive', 'lotus!ive', 'leaf!ive', 'rice!ive', 'rice!ive', 'rice!ive', 'rice!ive']
# ['mai!greasy', 'pork!greasy', 'fun!dry', 'chow!dry', 'family!loud', 'shu!greasy']
# ['service!excellent', 'perfection!service']
# ['', 'visit!special']
# ['bit!sweet', 'stuff!sweet', 'food!average', 'fusion!thai', 'thing!bit']
# ['', 'thing!only', 'chicken!only', 'puree!chicken']
# ['', 'salt!more', 'bit!salt']
# ['effort!kills', 'tho!effort']
# ['', 'list!extensive', 'sake!extensive']
# ['roll!good', 'spicy!good', 'tempura!awesome', 'tuna!good', 'appetizer!tempura', 'rock!awesome', 'shrimp!awesome']
# ['bit!died', 'service!great']
# ['']
# ['service!friendly']
# ['ambiance!stylish']
# ['taste!bad', 'mouth!bad', 'service!taste']
# ['waiter!intimidate', 'bit!little', 'self-respect!little']
# ['food!great']
# ['notch!top', 'service!top']
# ['sushi!heavenly', 'sushi!heavenly', 'restaurant!heavenly', 'sea!heavenly', 'urchin!heavenly', 'sushi!heavenly', 'sushi!heavenly']
# ['sushi!fresh']
# ['rice!good', 'ration!good']
# ['', 'food!prepared', 'impecable!food']
# ['dishes!great']
# ['food!good']
# ['somosas!dissapointing', 'chai!dissapointing', 'chole!dissapointing', 'dhosas!dissapointing', 'dhal!dissapointing']
# ['service!nice', 'varys!nice', 'day!nice', 'day!nice', 'day!nice', 'day!nice']
# ['kitchen!slow']
# ['food!bland']
# ['ambience!nice', 'lunch!best', 'conversation!ambience']
# ['river!-', 'weehawken!-', 'idea!-', 'top!-', 'view!-', 'chart!-', 'house!-']
# ['dessert!incredible', 'lava!incredible', 'cake!incredible']
# ['', 'bistro!small', 'path!small']
# ['restaurant!cozy']
# ['desserts!brilliant', 'soup!brilliant', 'food!average', 'onion!french', 'way!desserts']
# ['ambience!-', 'food!-', 'companion!-', 'trip!-', 'world!-']
# ['pizza!cold', 'cheese!cold']
# ['ingredients!fancy', 'pizza!good']
# ['meals!best', 'life!best', 'minnow!meals']
# ['seafood!amazing', 'wine!good', 'list!good', 'menu!ever-changing', 'surprises!menu']
# ['combination!unusual', 'ingredients!unusual', 'dishes!super-fresh']
# ['portion!great', 'pastrami!portion']
# ['shrimp!fried', 'wife!shrimp']
# ['', 'signs!japanese', 'menus!japanese', 'food!menus', 'waitstaff!menus']
# ['leon!gem', 'fare!prepared', 'bistro!prepared', 'village!leon', 'specials!good', 'gem!fare', 'atmosphere!warm', 'hip!fare']
# ['wife!enjoy', 'staff!enjoy']
# ['service!excellent', 'decor!great', 'food!delicious', 'portions!large']
# ['hostess!rude', 'point!hostess']
# ['oily!bland', 'food!bland']
# ['food!great', 'wine!great', 'times!many', 'place!many', 'service!food']
# ['wait!trouble', 'trouble!wait']
# ['glass!great', 'wine!great']
# ['service!great']
# ['people!friendly', 'new!friendly', 'york!friendly']
# ['', 'pizza!yummy']
# ['lunch!good', 'reviews!good']
# ['', 'sauce!watery', 'flavor!much', 'food!flavor']
# ['waitress!patient', 'food!phenomenal']
# ['service!prompt']
# ['pizza!great', 'service!great']
# ['', 'wait!small']
# ['block!magnificent', 'end!magnificent']
# ['sushi!best', 'city!best', 'hands!best']
# ['terrace!enjoy', 'garden!enjoy']
# ['nights!warm', 'restaurant!warm', 'kitchen!open', 'part!open']
# ['setting!intimate', 'service!intimate', 'occasion!special']
# ["d'!rude", 'maitre!rude']
# ['lounge!attraction']
# ['restaurant!romantic', 'raga!romantic']
# ['staff!helpful']
# ['waitress!-', 'table!-', 'bathroom!-', 'dinner!-', 'orders!-', 'toilet!-']
# ['everythig!loved']
# ['server!helpful']
# ['atmosphere!wonderful', 'evening!cool', 'avenue!6th']
# ['service!prompt']
# ['staff!nonsense']
# ['service!good']
# ['decour!pleasant', 'hall!noisy', 'restaurant!full']
# ['seating!prompt']
# ['decor!vibrant', 'boths!right', 'side!right', 'side!several', 'hall!right']
# ['', 'time!first', 'band!time', 'atmosphere!band', 'jazz!live']
# ['server!cool']
# ['laugh!good', 'bathrooms!hidden', 'decor!hidden']
# ['', 'staff!professional']
# ['thing!good', 'service!good', 'restaurant!thing']
# ['vibe!great', 'lots!great']
# ['atmosphere!liked']
# ['ambience!cute']
# ['atmosphere!noisy']
# ['takeout!great', 'tupperware!high', 'quality!high']
# ['visit!sure', 'manager!sure']
# ['service!slow', 'people!friendly']
# ['place!nice']
# ['ambience!delightful']
# ['service!horrible', 'ambience!great']
# ['restaurant!cute']
# ['ambience!dark']
# ['place!good', 'spot!hang']
# ['place!romantic']
# ['service!-', 'joint!-', 'price!-', 'category!-']
# ['service!proper', 'grazie!charm']
# ['place!cute', 'staff!cute', 'wait!nice']
# ['place!cool', 'service!prompt']
# ['room!elegant', 'dining!elegant', 'music!refreshing']
# ['service!impeccable', 'meal!present', 'menu!present']
# ['view!breathtaking', 'service!top', 'notch!top', 'wonderfull!top']
# ['service!impeccable', 'staff!service']
# ['service!excellent', 'place!small', 'date!service', 'occassion!special']
# ['place!fun']
# ['', 'staff!friendliest']
# ['place!-', 'lot!-', 'fun!-']
# ['experience!enjoyable']
# ['service!slow']
# ['', 'service!quick']
# ['delivery!-']
# ['zero!-', 'ambiance!-', 'boot!-']
# ['ambience!nice', 'service!great']
# ['', 'nothing!special', 'atmosphere!special', 'establishment!nothing']
# ['', 'owner!japanese', 'staff!japanese']
# ['trattoria!top', 'top!quaint']
# ['', 'room!back', 'secret!back']
# ['service!excellent']
# ['staff!great']
# ['service!great']
# ['staff!horrible']
# ['hostess!rude', 'waitress!rude']
# ['dessert!-', 'waitress!-', 'bill!-', 'chance!-', 'order!-']
# ['decor!nice', 'service!spotty']
# ['waitstaffs!nice']
# ['times!dissappointed', 'service!times']
# ['service!attentive']
# ['svc!rude', 'bit!svc', 'times!svc', 'esp!svc', 'group!big']
# ['experience!disappointing', 'desk!disappointing', 'atmosphere!experience']
# ['seats!uncomfortable']
# ['restaurant!cramped']
# ['bar!nice', 'cigar!nice', 'staff!great', 'patroon!bar']
# ['waitstaff!friendly']
# ['service!good', 'ambience!good', 'date!service', 'outing!date', 'group!date']
# ['', 'occassion!special', 'sort!special', 'candle!occassion']
# ['waiter!attentive', 'mark!attentive']
# ['atmosphere!great', 'hesititate!hate']
# ['', 'town!little']
# ['cafe!noir', 'noir!noir', 'dont!noir', 'jsut!noir', 'people!noir']
# ['service!terrible', 'thing!same', 'thing!several', 'people!different']
# ['waitress!concerned', 'waitress!concerned']
# ['things!work', 'thing!only', 'tips!only', 'america!things']
# ['tip!more', 'model/waitress!more', 'manager!more']
# ['staff!good', 'place!great']
# ['decor!charming']
# ['experience!worst', 'customer!worst', 'service!worst', 'weeks!experience', 'restaurant!worst']
# ['gentleman!much', 'manager!much', 'table!much', 'smile!much', 'order!much']
# ['reservations!-', 'times!-', 'hostess!-', 'name!-']
# ['weather!nice', 'table!snag', 'snag!outside']
# ['staff!nice', 'bathroom!unisex']
# ['', 'patrons!last', 'time!last', 'closing!patrons']
# ['staff!friendly', 'company!enjoy', 'meal!enjoy']
# ['', 'patio!back']
# ['place!nice']
# ['service!slow', 'bit!service']
# ['service!good']
# ['area!pleasant', 'garden!pleasant', 'herb!personal']
# ['service!excellent']
# ['waiter!nice']
# ['crowd!nice']
# ['waiter!okay', 'money!okay', 'guys!okay', 'outta!okay']
# ['staff!attentive', 'wait!attentive']
# ['service!bad']
# ['room!unattractive', 'clerks!unattractive', 'style!more', 'substance!more', 'folks!style']
# ['place!lovely']
# ['lawns!beautiful']
# ['place!great']
# ['murray!-', 'anything!-', 'service!-']
# ['service!awful']
# ['', 'sandwich!open', 'cheese!open', 'manager!sandwich']
# ['service!good']
# ['location!perfect']
# ['place!ghetto']
# ['atmoshere!great', 'bit!great']
# ['crew!best', 'winnie!best', 'staff!winnie', 'staff!crew']
# ['service!attentive']
# ['place!quiet']
# ['staff!pleasant', 'wait!pleasant', 'part!most', 'beautification!wonderful', 'fun!staff', 'way!wonderful', 'way!wonderful']
# ['part!best', 'atmosphere!best', 'ls!best', 'bts!atmosphere', 'night!late']
# ['taste!good', 'music!good', 'dj!taste', 'lady!in-house', 'nights!in-house']
# ['feature!great', 'terrace!great', 'suan!great']
# ['', 'staff!friendlier']
# ['', 'setting!casual']
# ['sum!dim', 'atmosphere!dim', 'wait!long', 'gig!typical', 'alternative!wait', 'tables!like', 'chinatown!sleek']
# ['service!friendly', 'atmosphere!casual']
# ['place!better']
# ['management!terrible']
# ['service!fast']
# ['place!beautiful']
# ['', 'restaurant!typical', 'nyc!typical', 'gimmick!typical', 'theme!typical']
# ['atomosphere!cozy', 'tables!cozy']
# ['ceiling!spectacular', 'room!main', 'dining!main']
# ['', 'patio!gigantic']
# ['months!warmer', 'seating!warmer', 'winter!outdoor']
# ['design!good', 'atmosphere!good']
# ['', 'opera!italian', 'everything!italian', 'jukebox!everything', 'strokes!jukebox']
# ['space!attractive', 'redone!attractive']
# ['seating!perfect', 'delight!seating']
# ['indoor!indoor']
# ['', 'decor!simple']
# ['jazz!-', 'duo!-', 'point!-']
# ['atmosphere!nice']
# ['scene!love', 'character!nice', 'light!nice', 'place!character']
# ['atmosphere!love', 'paris!atmosphere']
# ['restaurant!warm', 'city!new', 'friend!city']
# ['space!-', 'kind!-', 'alice!-', 'wonderland!-', 'setting!-']
# ['', 'place!hidden', 'bit!place']
# ['place!great']
# ['something!-', 'atmosphere!-', 'week!-']
# ['restaurant!nice']
# ['area!nice', 'garden!nice', 'months!area']
# ['place!recommend']
# ['view!nice', 'river!nice', 'nyc!river']
# ['', 'restaurant!dreamy']
# ['hookah!-']
# ['booths!most', 'eachother!most', 'couple!most']
# ['bathroom!disgusting', 'mens!disgusting']
# ['seating!great']
# ['', 'boths!small']
# ['belly!-', 'dancing!-', 'crowd!-']
# ['atmosphere!casual']

# %%
# import pandas as pd
# import re
# import math
# import numpy as np

# df = pd.read_csv('dataset/res16_baru.csv')

# dp_aspect, opinion_expand = double_propagation(op_set, preprocess(["I like the ambience, it's very dark and original."], False),
#                                                    df['target'], 'Results/ATE/dp.csv', True, df)

# %%
conj_DP = ['conj']
dep_DP = ['amod', 'prep', 'nsubj', 'csubj', 'xsubj', 'dobj', 'iobj']



# dep_DP = ['amod', 'prep', 'nsubj', 'csubj', 'xsubj', 'dobj', 'iobj',
#           'advmod', 'dep', 'cop', 'mark', 'nsubjpass', 'pobj', 'acomp', 'xcomp', 'csubjpass', 'poss']

# %%
dp_aspect
# Out:
# []

# %%
import pandas as pd

def preprocess(sentences):
    res = []
    for sentence in sentences:
        text = sentence.lower()
        res.append(text)
    return res

df = pd.read_csv('dataset/input.csv')
double_propagation(op_set, preprocess(df['review']), 'output.csv', True, df)
